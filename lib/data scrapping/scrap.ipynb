# %%
from bs4 import BeautifulSoup
import requests
import os
import time
from requests.exceptions import RequestException
import json

# %%
url = 'https://www.difelatsasione.co.za/a-re-bokeng-mor-a-motho-sotho/'

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

print(soup)

# %%
path = 'C:\\Users\\Justice Ntoi\\Downloads\\Lifela scrap\\Difela tsa Sione a collection of South African Hymns.html'


# Open and read the HTML file
with open(path, 'r', encoding='UTF-8') as file:
    content = file.read()

# Parse the HTML content with BeautifulSoup
soupB = BeautifulSoup(content, 'html.parser')

print(soupB.title.text)
# Out:
# Difela tsa Sione a collection of South African Hymns

# %% [markdown]
# # Download all Hymns.html

# %%
# Directory to store the downloaded pages
download_dir = 'C:\\Users\\Justice Ntoi\\Downloads\\Lifela scrap\\pages'
os.makedirs(download_dir, exist_ok=True)

tr_tag = soupB.find('tr', style="height: auto !important;")

# Initialize a counter for naming files
counter = 1

# Maximum number of retries
max_retries = 3

# If the <tr> tag is found, find all <li> tags within it
if tr_tag:
    li_tags = tr_tag.find_all('li')

    # Iterate through each <li> tag within the <tr> tag
    for li in li_tags:
        a_tag = li.find('a')
        if a_tag and 'href' in a_tag.attrs:
            url = a_tag['href']
            retries = 0
            while retries < max_retries:
                try:
                    # Send an HTTP request with headers
                    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
                    response = requests.get(url, headers=headers)
                    response.raise_for_status()  # Check for HTTP errors

                    # Define the file path with a numbered name
                    file_path = os.path.join(download_dir, f'{counter}.html')

                    # Write the HTML content to a file
                    with open(file_path, 'w', encoding='UTF-8') as file:
                        file.write(response.text)

                    print(f'Downloaded {url} to {file_path}')

                    # Increment the counter
                    counter += 1

                    # Break the retry loop on success
                    break

                except RequestException as e:
                    retries += 1
                    print(f'Failed to download {url}: {e}, retrying ({retries}/{max_retries})')
                    time.sleep(3)  # Delay before retrying

            if retries == max_retries:
                print(f'Failed to download {url} after {max_retries} retries.')

        # Add a delay between requests
        time.sleep(2)

    print('All pages have been downloaded.')
else:
    print('No <tr> tag found with the specified style.')
# Out:
# Downloaded http://www.difelatsasione.co.za/a-re-bokeng-mor-a-motho-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\1.html
# Downloaded http://www.difelatsasione.co.za/alleluya-ho-jehova-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\2.html
# Downloaded http://www.difelatsasione.co.za/a-re-phokoleng-sefela-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\3.html
# Downloaded http://www.difelatsasione.co.za/atamelang-ho-jehova-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\4.html
# Downloaded http://www.difelatsasione.co.za/alleluya-go-jehova/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\5.html
# Downloaded http://www.difelatsasione.co.za/bokang-jehova/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\6.html
# Downloaded http://www.difelatsasione.co.za/bokangmopi-lemoloki/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\7.html
# Downloaded http://www.difelatsasione.co.za/balopollwa-ba-morena/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\8.html
# Downloaded http://www.difelatsasione.co.za/ba-bitseng-le-ba-qophelle/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\9.html
# Downloaded http://www.difelatsasione.co.za/bonang-rato-le-lekaakang/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\10.html
# Downloaded http://www.difelatsasione.co.za/batho-bohle-ba-merabe/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\11.html
# Downloaded http://www.difelatsasione.co.za/bakgethwa-binang-alleluya/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\12.html
# Downloaded http://www.difelatsasione.co.za/bokang-bokang-moloki/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages
/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\353.html
# Downloaded http://www.difelatsasione.co.za/utlwa-morutuwa/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\354.html
# Downloaded http://www.difelatsasione.co.za/utlwang-lentwe-lea-tlerola/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\355.html
# Downloaded http://www.difelatsasione.co.za/utlwang-sello-sa-dichaba/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\356.html
# Downloaded http://www.difelatsasione.co.za/utlwang-taba-e-molemo/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\357.html
# Downloaded http://www.difelatsasione.co.za/utlwang-taba-tse-molemo/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\358.html
# Downloaded http://www.difelatsasione.co.za/utlwang-utlwang-ditaba/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\359.html
# Downloaded http://www.difelatsasione.co.za/utlwa-sefefo-sa-moya/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\360.html
# Downloaded http://www.difelatsasione.co.za/wa-nkalosa-go-ntekane/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\361.html
# Downloaded http://www.difelatsasione.co.za/wena-jesu-wena-feela/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\362.html
# Downloaded http://www.difelatsasione.co.za/fatse-le-teng-la-nyakallo-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\363.html
# Downloaded http://www.difelatsasione.co.za/fatse-le-teng-la-nyakallo-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\364.html
# Downloaded http://www.difelatsasione.co.za/fatse-le-teng-la-nyakallo-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\365.html
# Downloaded http://www.difelatsasione.co.za/fatse-lea-feta-le-ntse-le-hula-sotho/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\366.html
# Downloaded http://www.difelatsasione.co.za/fatseng-la-bomadimabe/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\367.html
# Downloaded http://www.difelatsasione.co.za/fatseng-lena-hase-hae-ha-eso/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\368.html
# Downloaded http://www.difelatsasione.co.za/ea-renang-ka-go-sa-feleng/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\369.html
# Downloaded http://www.difelatsasione.co.za/ea-u-pate-dillo/ to C:\Users\Justice Ntoi\Downloads\Lifela scrap\pages\370.html
# All pages have been downloaded.

# %%
# Path to JSON file
hymns_file = 'hymns sione.json'

# Path to the new JSON file to be created
new_hymns_file = 'hymns_sione.json'

# Load and read the JSON file
with open(hymns_file, 'r', encoding='UTF-8') as file:
    hymns_data = json.load(file)

# Directory containing HTML files
html_dir = 'C:\\Users\\Justice Ntoi\\Downloads\\Lifela scrap\\pages'

# List to store the new hymn entries with lyrics
new_hymns_data = []

# Initialize the ID counter
new_id = 1

# Iterate over each HTML file in the directory
for filename in os.listdir(html_dir):
    if filename.endswith('.html'):
        html_path = os.path.join(html_dir, filename)

        # Open and read the HTML file
        with open(html_path, 'r', encoding='UTF-8') as file:
            content = file.read()

        # Parse the HTML content with BeautifulSoup
        hym = BeautifulSoup(content, 'html.parser')

        # Find the title in the HTML file
        try:
            html_title = hym.find(class_='entry-title entry--item h2').text.strip()
        except AttributeError:
            # If the class is not found, continue with the next file
            print(f"No title found in {filename}")
            continue

        # Search for the matching title in the JSON data
        for hymn in hymns_data:
            if hymn['title'].strip() == html_title:
                # Extract paragraphs between ttr_start and ttr_end
                ttr_content = hym.find('div', class_='ttr_start')
                ttr_end = hym.find('div', class_='ttr_end')
                if ttr_content and ttr_end:
                    paragraphs = []
                    for elem in ttr_content.find_all_next():
                        if elem == ttr_end:
                            break
                        if elem.name == 'p':
                            paragraphs.append(elem.get_text(separator='\n').strip())

                    # Join paragraphs into a single string with "\r\n\r\n" separator
                    lyrics = "\r\n\r\n".join(paragraphs)

                    # ============================
                    # Replace <br> tags with newlines in the paragraphs
                    lyrics = lyrics.replace('<br />', '\n').replace('<br>', '\n')

                    # Remove excessive tabs, spaces, and newlines
                    lyrics = "\r\n\r\n".join([line.strip() for line in lyrics.splitlines() if line.strip()])
                    # ============================

                    # Create a new hymn entry with lyrics and add it to new_hymns_data
                    new_hymn_entry = {
                        "id": str(new_id),
                        "title": hymn['title'],
                        "link": hymn['link'],
                        "lyrics": lyrics
                    }
                    new_hymns_data.append(new_hymn_entry)
                    
                    # Increment the ID counter
                    new_id += 1

                    # Print the lyrics variable (for verification)
                    print(f"Lyrics for {html_title}:\n{lyrics}")

                else:
                    print("Content not properly found between ttr_start and ttr_end.")
                print("\n" + "-"*40 + "\n")
                break
    else:
        print(f"No matching title found in {filename}.")

# Save the new hymns data with lyrics to the new JSON file
with open(new_hymns_file, 'w', encoding='UTF-8') as file:
    json.dump(new_hymns_data, file, ensure_ascii=False, indent=4)

print(f"New hymns data with lyrics has been saved to {new_hymns_file}.")
# Out:
# Lyrics for A re bokeng Mor'a motho:
# 1  A re bokeng Mor'a motho;
#
# O re lopolotse; (bis)
#
# Mali a hae a boholo
#
# A ka re ntša ho shoeng.
#
# 2 'Mele oa Jesu ke sejo
#
# Pelong e lapileng,(bis)
#
# Mali a Jesu ke seno
#
# Moeeng o nyoriloeng.
#
# 3 Maqeb'a hae ke ho fola
#
# Ho batho ba babang; (bis)
#
# Lefu la hae ke ho phela
#
# Ho bam o lumelang.
#
# ----------------------------------------
#
# Lyrics for Bonang, rato le lekaakang:
# 1. Bonang rato le lekaakang
#
# La Modimo Ntate,
#
# Ha e le rona ba bitswang
#
# Bana ka sebele!
#
# Bonang, ke le lekaakang
#
# Lerato la Modimo Ntate,
#
# Kamoo roona re bitswang
#
# Bana ba hae ke 'nete!
#
# 2. Lefatshe ha le re tsebe,
#
# Re hlora ke hona,
#
# Ha e-ba jwale le Kreste,
#
# Morena wa rona.
#
# Bonang, ke le lekaakang, …
#
# 3. Ha se e-s'o bonahale
#
# See re tla ba sona;
#
# Re tla 'mona a hlahile,
#
# Re tshwane le eena.
#
# Bonang, ke le lekaakang, …
#
# 4. Re ipolokeng ka tshepo,
#
# Re hloeke dipelo,
#
# Re dutse ka hlolohelo,
#
# Re lebella Jesu.
#
# Bonang, ke le lekaakang, …
#
# ----------------------------------------
#
# Lyrics for Jesu ke tla ke hlomohile:
# 9.8.9.8.
#
# Jesu ke tla ke hlomohile,
#
# Oho, nchebe ka mosa!
#
# Ke litšila, u li hlakole;
#
# Ke bohloko, o mpholise.
#
# Otlolla he letsoho lela
#
# Le neng le ntlhabelo khale;
#
# Ama pelo ea ka lona,
#
# Leqeba la ka le fole.
#
# Ke tlile ke ikokobetsa
#
# Ke lentsoe lena la pallo,
#
# Le reng ho 'na: Ha u khathetse,
#
# Tlo, ke tla u fa phomolo.
#
# Jesu, ke tšepa uena fela,
#
# Ha ho o mong ea ka nthusang;
#
# Ha u sa ntlel , ke tla fela,
#
# Utloa ngoana hao oa ea llang!
#
# Bona, ha ke sa ntse ke bitsa,
#
# Ka khotso u s'u nchabetse;
#
# Li kae be tse neng li ntelisa?
#
# Jesu, ahe, u nthusitse!
#
# ----------------------------------------
#
# Lyrics for Jesu ke tla ke hlomohile:
# 9.8.9.8.
#
# Jesu ke tla ke hlomohile,
#
# Oho, nchebe ka mosa!
#
# Ke ditshila, o di hlakole;
#
# Ke bohloko, o mphodise.
#
# Otlolla he letsoho lela
#
# Le neng le ntlhabelo khale;
#
# Ama pelo ya ka lona,
#
# Leqeba la ka le fole.
#
# Ke tlile ke ikokobetsa
#
# Ke lentswe lena la pallo,
#
# Le reng ho 'na: Ha o khathetse,
#
# Tlo, ke tla o fa phomolo.
#
# Jesu, ke tshepa wena fela,
#
# Ha ho o mong ya ka nthusang;
#
# Ha o sa ntlel , ke tla fela,
#
# Utlwa ngwana hao wa ya llang!
#
# Bona, ha ke sa ntse ke bitsa,
#
# Ka khotso o s'u nchabetse;
#
# Di kae be tse neng di ntedisa?
#
# Jesu, ahe, o nthusitse!
#
# ----------------------------------------
#
# Lyrics for Jesu Molis'a molemo:
# 1. Jesu Molis'a molemo,
#
# Re tlile le ngoana;
#
# Ho mo tšoela Molimo,
#
# A abeloe oona. bis
#
# 2. Mahlo a hao, Mor'a motho,
#
# A shalime ngoana;
#
# Mo amohele kajeno,
#
# A khotse ho uena. bis
#
# 3. Libe li mo khomaretse,
#
# U mo hlatsoe tsona,
#
# Re tla mo tšela ka metsi,
#
# Mo tšele ka Moe. bis
#
# 4. Lesea lena le hole,
#
# Matleng le bohlaleng;;
#
# Ha le falla, le fallele,
#
# Leholimong, botleng. bis
#
# ----------------------------------------
#
# Lyrics for Jesu Mon'a ka:
# 1. Jesu, Mong'a ka, o filoe borena
#
# Lehodimong le lefatsheng,
#
# Kahohle-hohle le ka ho sa feleng.
#
# Ho ya 'ne ho buse wena.
#
# Lebitso la Jesu
#
# Le bokoe, le roriswe hohle;
#
# Bitso lena la Jesu le ratehang,
#
# Ho rona le letle, le letle
#
# 2. Lebitso la hao le tla tuma hohle
#
# Dipheletsong tsa lefatshe;
#
# Ho tla 'ne ho haswe lona le 'notshe,
#
# Lebitso la hao le letsle
#
# Lebitso la Jesu, …
#
# 3. Merabe-rabe le tsohle diboko,
#
# Ba mefuta ba hloyaneng,
#
# Ba ya kopana ka lentswe le le leng,
#
# Ho o fapha ka dithoko.
#
# Lebitso la Jesu, …
#
# 4. Ha ba o roka, ba neeletsana,
#
# Lehodimo ha le khutse;
#
# Le tshwara dithoko tsa ba lefatshe,
#
# Ho o tumisa, Morena.
#
# Lebitso la Jesu, …
#
# 5. Lebitso la hao a le ke le hole,
#
# Molaodi wa marena!
#
# U filoe 'muso, le hlompho le khanya,
#
# Bohle ba o a nanela.
#
# Lebitso la Jesu, …
#
# ----------------------------------------
#
# Lyrics for Jesu Moren'a ka, ke re:
# 13.12.13.12.
#
# 1.	Jesu, Moren'a ka, ke re, u nkatamele,
#
# Ke ntse ke u llela, ke le mahlomoleng!
#
# Tlo ka matšeliso, tlo, uena, ka sebele,
#
# Oka pelo ea ka ee u e hlebileng!
#
# 2.	Leha u nchapile, ua nkotla habohloko
#
# Ke ntse ke u tseba hoba u mohau;
#
# Thupaa kea ea ka, u ntaea ka lereko,
#
# U tl'u mphe kabelo khalalelong ea hao,
#
# 3.	Hlohonolofatsa haholo kotlo tsena,
#
# Li sebetse tsohle tsee u li hopotseng;
#
# Ho 'na e be peo e beang litholoana
#
# Tsa pako, tsa khotso, tsa rato le letleseng.
#
# 4.	Ha ke sa le mona, u ntiise hle, ke phethe
#
# Mosebetsi oohle oo ke o abetsoeng;
#
# Ke 'ne ke bontše ba lefifing, ke ba rute
#
# Rato le leholo lee u ba ratileng.
#
# 5.	Nke ke ka khathala, e se e tla ba nako;
#
# Mong'a rona, u se u tla bonahala!
#
# Ke'ng, leha lefatšeng nka jala ka meokho?
#
# Thabong e sa feleng ke tla ea kotula.
#
# ----------------------------------------
#
# Lyrics for Jesu Moren'a ka, ke re:
# 13.12.13.12.
#
# 1. Jesu, Moren'a ka, ke re, o nkatamele,
#
# Ke ntse ke o llela, ke le mahlomoleng!
#
# Tlo ka matshediso, tlo, wena, ka sebele,
#
# Oka pelo ya ka ee o e hlabileng!
#
# 2. Leha o nchapile, wa nkotla habohloko
#
# Ke ntse ke o tseba hoba o mohau;
#
# Thupaa ke ya ya ka, o ntaya ka lereko,
#
# U tl'u mphe kabelo khalalelong ya hao,
#
# 3. Hlohonolofatsa haholo kotlo tsena,
#
# Di sebetse tsohle tsee o di hopotseng;
#
# Ho 'na e be peo e beang ditholwana
#
# Tsa pako, tsa khotso, tsa rato le letleseng.
#
# 4. Ha ke sa le mona, o ntiise hle, ke phethe
#
# Mosebetsi oohle oo ke o abetsweng;
#
# Ke 'ne ke bontshe ba lefifing, ke ba rute
#
# Rato le leholo lee o ba ratileng.
#
# 5. Nke ke ka khathala, e se e tla ba nako;
#
# Mong'a rona, o se o tla bonahala!
#
# Ke'ng, leha lefatsheng nka jala ka meokho?
#
# Thabong e sa feleng ke tla ya kotula.
#
# ----------------------------------------
#
# Lyrics for Jesu motswalle ya nkileng:
# 8.7.8.7.
#
# 1. Jesu, motswalle ya nkileng
#
# Melato le makhopo,
#
# 'Na, mohloki, ke sitwa ke'ng
#
# Ho o rapella tsohle?
#
# Ke ntse ke itima khotso,
#
# Ke tlala pelaelo,
#
# Ha ke sa ise ditaba
#
# Ho wena ka thapelo.
#
# 2. ditsietsing, mahlomoleng,
#
# Ha ke imelwa hampe,
#
# 'Na, motswafi, ke sitwa ke'ng
#
# Ho tshepa pallo tsa hao?
#
# Ha ke na e mong lefatsheng
#
# Ya nkutlwelang bohloko,
#
# Ya ka ntokollang boimeng,
#
# Ha e se wena Jesu.
#
# 3. dintoeng tse thata tsa dibe,
#
# Ha sera se ya le 'na,
#
# 'Na, mohlolwa, ke sitwa ke'ng
#
# Ho ipeha ho wena?
#
# Nthute ka matsatsi 'ohle
#
# Ho belaela ka 'na,
#
# Ke rapele ke tshepile
#
# Kutlo ya hao le matla.
#
# ----------------------------------------
#
# Lyrics for Jesu naledi ya ho sa:
# 1 Jesu, naledi ya ho sa, – o nchabisetse ka mosa
#
# Letsatsi la ho thaba;
#
# Mafube a mechaedi, – A nketele ka lesedi,
#
# Tsatsi le be le chabe!
#
# Amen, Amen!
#
# U bonese- o hlwekise- Moya wa ka,
#
# Ke hlophehe ka ho loka!
#
# ----------------------------------------
#
# Lyrics for Jesu naleli ea ho sa:
# 1 Jesu, naleli ea ho sa, – U nchabisetse ka mosa
#
# Letsatsi la ho thaba;
#
# Mafube a mechaeli, – A nketele ka leseli,
#
# Tsatsi le be le chabe!
#
# Amen, Amen!
#
# U bonese- U hloekise- Moea oa ka,
#
# Ke hlophehe ka ho loka!
#
# ----------------------------------------
#
# Lyrics for Jesu o nts'a bitsa:
# 8.7.8.7.D.
#
# 1. Jesu o nts'a bitsa, o re:
#
# Ana ke tla roma mang?
#
# Kotulo e kholo ruri;
#
# Ke mang na, ke mang ya yang?
#
# Morena o nts'a tlerola,
#
# Moputso o mongata;
#
# Na ke mang ya ya araba:
#
# Roma 'na, ha o rata? (bis)
#
# 2. Leha o sa rongoe hole
#
# Ho ruta bahedene,
#
# Bona ba tletse kahohle,
#
# Le kwano ba haufi.
#
# Menono ha o e hloka
#
# Ho e abela Jesu,
#
# Abela tsa bofutsana,
#
# Mo abele ka pelo! (bis)
#
# 3. Leha o sitwa ho ruta
#
# Ka matla, ka hlalefo,
#
# Na o ka sitwa ho pheta:
#
# Modimo o lerato?
#
# Ha o se na matlanyana
#
# Ho tsosa ba baholo,
#
# Ya bokella dikonyana,
#
# U di tlise ho Jesu. (bis)
#
# 4. Leha o sa beoe qhooeng
#
# Ho tumisa tsa khotso,
#
# U ka rapela sephiring,
#
# E ntse e le tshebetso.
#
# Rapella, 'me o tshehese
#
# Bahlanka ba Modimo,
#
# Etlaba o seditse
#
# Tse kholo, tse molemo. (bis)
#
# 5. dumela lentswe la Jesu:
#
# Ana ke tla roma mang?
#
# Bona, kotulo e kholo;
#
# Na o sa diehelang?
#
# Dumela ho ya kahohle
#
# Moo ho ratang Morena;
#
# Phakisa, mo arabele;
#
# E-re: Roma, roma 'na! (bis)
#
# ----------------------------------------
#
# Lyrics for Batho bohle ba merabe:
# 1 Batho bohle ba merabe,
#
# Ba basweo le ba batsho,
#
# Bohle ke baetsadibe,
#
# Batho ba melato-lato.
#
# 2 Modimo o n'o ngodile
#
# Melao pelong tsa bona,
#
# Ba e roba eohle-eohle,
#
# Ba ikhantshetsa Morena.
#
# 3 Jo, ke ba tshwanelang lefu,
#
# Ho timela ho sa feleng;
#
# Pel'a Moren'e moholo
#
# Ha ho ya mong ya lokileng.
#
# 4 Empa ho hlahile Jesu,
#
# Mor'a Modimo. 'Moloki;
#
# A ba lefela melato,
#
# Tefong ha tsholoha madi.
#
# 5 Sefapanong, ka lerato,
#
# A shwa; batho ba 'molaya.
#
# A ba qobela dikotlo,
#
# Ba dumelang ba pholoha.
#
# ----------------------------------------
#
# Lyrics for Jesu o nts'a mpoloka:
# 1 Jesu o nts'a mpoloka,
#
# Moya, 'mele, le pelo;
#
# O mpoloka ka mehla,
#
# Motsheare, bosiu.
#
# Jesu wa mpoloka,
#
# Jesu, 'moloki wa ka,
#
# Ka mehla wa mpoloka
#
# 2 Jesu o nts'a mpoloka,
#
# Ke le hae, kapa naheng;
#
# Leha ke ntse ke thaba,
#
# kapa ke le maswabing.
#
# Jesu wa mpoloka…
#
# 3 Jesu o nts'a mpoloka,
#
# Leha ke le monate;
#
# Mohlomong ha ke baba,
#
# Le teng ha a ntebale.
#
# Jesu wa mpoloka…
#
# 4 Jesu o nts'a mpoloka,
#
# Melekong e bohale,
#
# E sa mpheng le sebaka,
#
# tshepo e be fele.
#
# Jesu wa mpoloka…
#
# 5 Jesu o nts'a mpoloka,
#
# A le haufi-ufi;
#
# O disa pelo ya ka
#
# O nkhatshetsa lefifi
#
# Jesu wa mpoloka…
#
# 6 Jesu o nts'a mpoloka,
#
# Mohla lefu le hlahang,
#
# Ke setshabelo sa ka;
#
# Na nka thothomela jwang?
#
# Jesu wa mpoloka…
#
# 7 Jesu o nts'a mpoloka…
#
# Motseng wa hae o motle
#
# A nketse wa bohlokwa,
#
# Ya ratwang ka sebele.
#
# Jesu wa mpoloka…
#
# ----------------------------------------
#
# Lyrics for Jesu o shoetse batho:
# 1 Jesu o shoetse batho,
#
# Ba tle ba loeloe libeng;
#
# O lefile melato,
#
# Ke e sa baloeng!
#
# Ke lona lehlo'nolo
#
# Ha re tla ka tumelo
#
# Ho  tla kopa tšoarelo
#
# Ho eena.
#
# A re thabeng, baena,
#
# Re leboheng, re bokeng;
#
# A re rateng Morena
#
# Ea re ratileng.
#
# ----------------------------------------
#
# Lyrics for Jesu o shoetse batho:
# 1 Jesu o shoetse batho,
#
# Ba tle ba lweloe dibeng;
#
# O lefile melato,
#
# Ke e sa baloeng!
#
# Ke lona lehlo'nolo
#
# Ha re tla ka tumelo
#
# Ho tla kopa tshwarelo
#
# Ho eena.
#
# A re thabeng, baena,
#
# Re leboheng, re bokeng;
#
# A re rateng Morena
#
# Ya re ratileng.
#
# ----------------------------------------
#
# Lyrics for Jesu o tla rena hohle:
# 1. Jesu o tla rena hohle,
#
# Hodimo le lefatsheng;
#
# A khumameloe ke bohle,
#
# Mangeloi le batho.
#
# Borena, poko, khanya,
#
# Ke tsa hae mehleng eohle!
#
# Alleluya!, (ter) Amen!
#
# 2. Morena, busaka mehla,
#
# Khanya pel'a dichaba;
#
# Marena a o nyehelle,
#
# A ipee ho wena.
#
# Borena, poko, khanya, …
#
# 3. Lefatshe le o mamele
#
# Ka kutlo ya sebele;
#
# E se be ka ho qobellwa,
#
# E tl'e be ka ho rata,
#
# Borena, poko, khanya, …
#
# 4. Morena, hlaha kapele,
#
# Bonahala ho bohle:
#
# Dira tsa hao o di hlotse,
#
# U hlabanne, o fentse.
#
# Borena, poko, khanya, …
#
# ----------------------------------------
#
# Lyrics for Jesu, rato la hao:
# Jesu, rato la hao – o mphile lona;
#
# (O Jesus, what a wonderful love you have given me)
#
# Ke molato wa hao, – Ke tla o fa’ng?
#
# (I owe you so much that i have nothing to offer you )
#
# Ke inea wena, – ka ‘mele le moya;
#
# (I give myself to you, both body and soul)
#
# Ke ntsha hanyenyane, o mpha tsohle.
#
# (You are everything to me)
#
# Ntaele, Morena, – Ke mofo wa hao;
#
# (Show me the way Lord, I am your servant)
#
# Thato ke tla etsa – ya hao eohle.
#
# (Your will i will do, all of your will)
#
# Ha e ka nkimela, – dumela, o ntlatse;
#
# (If it becomes too heavy on me, I believe that you will carry me)
#
# Le ho sitwa haka – U ntshwarele!
#
# (even in my weakness, forgive me Lord)
#
# Ke be motshepuwa – Sechabeng sa hao,
#
# (I want to be a faithful servant among your people)
#
# Esita le mona – Fatsheng lena.
#
# (In this world)
#
# Nke ke o khahlise, – Ke iketse mora,
#
# (I want to please you as your child)
#
# U tl’u khahloe ke ‘na – Moren’a ka.
#
# (So that you can be pleased with me my Lord)
#
# Sefapano saka – Ke tla se jara,
#
# (I will carry my cross)
#
# U le ka mora’ ka, – o ntjarisa.
#
# (with you beside me)
#
# Ho timele bo’na, ho tswaloe bowena,
#
# (until all in me is lost that i may be found in you)
#
# Ho tl’o ahe ha ka – wena fela.
#
# (and you alone make your dwelling in me)
#
# ----------------------------------------
#
# Lyrics for Jesu, rato la hao:
# 1.	Jesu, rato la hao –  U mphile lona;
#
# Ke molato oa hao, – Ke tla u fa'ng?
#
# Ke inea uena, – ka 'mele le moea;
#
# Ke ntša hanyenyane, U mpha tsohle.
#
# 2.	Ntaele, Morena, – Ke mofo oa hao;
#
# Thato ke tla etsa –  Ea hao eohle.
#
# Ha e ka nkimela, – Lumela, u ntlatse;
#
# Le ho sitoa haka – U ntšwarele!
#
# 3.	Ke be motšepuoa –  Sechabeng sa hao,
#
# Esita le mona –  Fatšeng lena.
#
# Nke ke u khahlise, – Ke iketse mora,
#
# U tl'u khahloe ke 'na –  Moren'a ka.
#
# 4.	Sefapano saka –  Ke tla se jara,
#
# U le ka mora' ka, – U ntjarisa.
#
# Ho timele bo'na, ho tsoaloe bouena,
#
# Ho tl'o ahe ha ka –  Uena fela.
#
# ----------------------------------------
#
# Lyrics for Jesu, u mpone he ke khathetse:
# 10.10.10.10.10.10.
#
# 1.	Jesu, u mpone ha ke khathetse,
#
# Ke lapile, ke nyahame pelo;
#
# Mona feelleng, u ntokiselitse (bis)
#
# Selallo, mokete o moholo. (bis)
#
# 2.	Ua 'mema le 'na, moetsalibe,
#
# Ke je, ke noe, ke thabe le uena;
#
# 'Mele oa hao ke bona bohobe, (bis)
#
# Ke noa le mali a hao, Morena. (bis)
#
# 3.	U ipha 'na, uena ka sebele,
#
# Ke khora matla, khotso le thabo;
#
# Nka batla  kae menate esele, (bis)
#
# Nka lakatsa'ng ha u mpha hakalo? (bis)
#
# 4.	Ana ho setse'ng ka ntle ho uena,
#
# Uena ea kakatletseng ntho tsohle,
#
# Uena, Monghali, ea ratoang ke 'na, (bis)
#
# Uena, Jesu, ea nthatileng pele?
#
# 5.	Ahe, Jesu, Ahe, Moren'a ka!
#
# U mphile, ke jele; e, ke khotše.
#
# U fanne haholo, kea boka, (bis)
#
# Ka matla a hao ke matlafetse. (bis)
#
# 6.	Ha ke tloha mona, ke tsamaea,
#
# Nke ke ka arohana le uena;
#
# Hohle ho pheleng le ho shoeng  ha ka, (bis)
#
# Jesu, ke tla 'ne ke be le uena. (bis)
#
# ----------------------------------------
#
# Lyrics for Jesu, o mpone he ke khathetse:
# 10.10.10.10.10.10.
#
# 1. Jesu, o mpone ha ke khathetse,
#
# Ke lapile, ke nyahame pelo;
#
# Mona feelleng, o ntokiseditse (bis)
#
# Selallo, mokete o moholo. (bis)
#
# 2. wa 'mema le 'na, moetsadibe,
#
# Ke je, ke nwe, ke thabe le wena;
#
# 'Mele wa hao ke bona bohobe, (bis)
#
# Ke nwa le madi a hao, Morena. (bis)
#
# 3. U ipha 'na, wena ka sebele,
#
# Ke khora matla, khotso le thabo;
#
# Nka batla kae menate esele, (bis)
#
# Nka lakatsa'ng ha o mpha hakalo? (bis)
#
# 4. Ana ho setse'ng ka ntle ho wena,
#
# Wena ya kakatletseng ntho tsohle,
#
# Wena, Monghadi, ya ratwang ke 'na, (bis)
#
# Wena, Jesu, ya nthatileng pele?
#
# 5. Ahe, Jesu, Ahe, Moren'a ka!
#
# U mphile, ke jele; e, ke khotshe.
#
# U fanne haholo, ke ya boka, (bis)
#
# Ka matla a hao ke matlafetse. (bis)
#
# 6. Ha ke tloha mona, ke tsamaya,
#
# Nke ke ka arohana le wena;
#
# Hohle ho pheleng le ho shweng ha ka, (bis)
#
# Jesu, ke tla 'ne ke be le wena. (bis)
#
# ----------------------------------------
#
# Lyrics for Joale, re utloile litaba:
# 1. Joale, re utloile litaba
#
# Tse tsoang ho Morena Jesu;
#
# Rea leboha, rea li thabela,
#
# Li re kholisa lipelo.
#
# 2. Joale, re tla bea thapelo
#
# Ho Moea o re utloisang,
#
# O tle o re nee tumelo,
#
# Le pelo tse o khahlisang.
#
# 3. Leha litsebe li mametse,
#
# Jalo li ka lula fela.
#
# Moea, u tle, u li nosetse,
#
# Peo e tsebe ho mela.
#
# 4. Bohle re ne re khelohetse
#
# Tseleng e isang tahlehong;
#
# U re hule, re u latele
#
# Tseleng, e lebang bophelong.
#
# 5. Satane, tau e bohale,
#
# O rata ho re timetsa.
#
# Uk'u re sitse ka boglale,
#
# A se hlole a re thetsa.
#
# ----------------------------------------
#
# Lyrics for Jo, ho lefifi, Ntate:
# 1 Jo, ho lefifi ntate,| 'me maru
#
# A thibane hohle, a le matsho!
#
# A | nts'a duma; |jo, ho tla sefefo!
#
# Rare, o 'nenese ka | letsoho;
#
# Ke lahlehile, nkise hae,
#
# Nkise hae, nkise hae;
#
# Ke 'na ngwana wa hao!
#
# 2 Le ipatile, ntate,| letsatsi;
#
# Ke mong, ke tshohile ke tsietsi;
#
# Ho | tetema | tshepo le tumelo.
#
# Rare, o 'nenese ka | letsoho;
#
# Oho, o nkise leseding,
#
# Leseding, leseding;
#
# Ke 'na ngwana wa hao!
#
# 3 Tsela e hole, ntate, | e hole;
#
# Jo, ke khathetse, ke tenehile!
#
# Nka | fihla neng, |ke bone phomolo?
#
# Rare, o 'nenese ka | letsoho;
#
# Oho, o nkise phomolong;
#
# Phomolong, phomolong;
#
# Ke 'na ngwana wa hao!
#
# 4 Tsela e thata ntate, | e thata;
#
# E majoe a khopang, e meutlwa.
#
# Ke | se ke le | maqeba le dillo;
#
# Rare, o 'nenese ka | letsoho;
#
# Oho, o nkise monateng,
#
# Monateng, monateng;
#
# Ke 'na ngwana wa hao!
#
# 5 Jo sefapano Ntate, | le sona
#
# Se bohloko-hloko, sea nkimela!
#
# Ke | se jere, | leha ho le jwalo;
#
# Rare, o 'nenese ka | letsoho;
#
# Ntshedise, nkise nyakallong,
#
# Nyakallong, nyakallong;
#
# Ke 'na ngwana wa hao!
#
# 6 Se fele pelo Ntate,| ha ke lla,
#
# U sebete, o ntsose molota,
#
# Le- | hodimong, | ke habe ka thabo
#
# Rare, o 'nenese ka | letsoho;
#
# Ke hlolohetswe, nkise hae,
#
# Nkise hae, nkise hae;
#
# Ke 'na ngwana wa hao!
#
# ----------------------------------------
#
# Lyrics for Bakhethwa, binang alleluya:
# 1. Bakhethwa, binang alleluia,
#
# Phokolang fela sa thabo;
#
# Jesu, 'Moloki wa lona,
#
# O tsohile: ke nyakallo.
#
# E, mo-khora-mahlomola,
#
# Eena, molahluwa wa batho,
#
# Kajeno o hlotse lebitla.
#
# Thabang: ho tsohile Jesu!
#
# 2. Bakhethwa, binang alleluia,
#
# Thabang, hlakolang maswabi
#
# Ya neng a shwele wa phela,
#
# O tsohile bafung, 'Moloki.
#
# Lebitla le bulehile,
#
# Le botsho ba lona bowa khanya.
#
# Nyakallang, Jesu o tsohile:
#
# Binang, binang alleluia!
#
# 3. Bakhethwa, binang alleluia,
#
# Tsa lefu di nathohile;
#
# Jesu o hlotse lebitla,
#
# Ho bola ha ho mo nkhele.
#
# Khothalang, le be le tshepo,
#
# Ha le san a ho tshoha lefu,
#
# Phokolang sefela sa hlolo!
#
# O le hloletse le lefu.
#
# 4. Bakhetwa, binang alleluia,
#
# Thabang le ba pholohileng!
#
# Hammoho le Mong'a lona
#
# Le phele ka ho sa feleng.
#
# Tsenene e kae ya lefu,
#
# Le ho tshabeha ha lebitla?
#
# Le nyakalleng, ho fentse Jesu!
#
# Tlatsang, binang alleluia!
#
# ----------------------------------------
#
# Lyrics for Jo, ho phela ha rona ke'ng:
# 1 Jo, ho phela ha rona ke'ng?
#
# Bokhabane, matla,
#
# Ke toro e re hapileng
#
# Ke moholifela
#
# 2 Bochaba, litaba, merero,
#
# Bosea, boqheku,
#
# Lefu ha le setse letho,
#
# Lefu le sehloho
#
# 3 Leha re ka itšoarella
#
# Ka tse ngata-ngata
#
# Lefu lea re khohola,
#
# Rea kukoa, rea feta.
#
# 4 Leha re ka qea-qea
#
# Lefu le bohale!
#
# Lintho tsohle lia re siea,
#
# Re siisoa tsohle
#
# 5 Empa, tšenyehong e kalo,
#
# Uena, u sa sala,
#
# Uena, Moren'a bophelo,
#
# Fika la ka mehla.
#
# 6 Ho rona u setšabelo
#
# Sa ka mehla eohle;
#
# Ha re na ho tšoha letho
#
# Ha re u tšepile
#
# 7 Oho! U re hlalefise,
#
# Re tele tse felang;
#
# Morena, u re ruise
#
# Lintho tse hlolehang.
#
# 8  Ha re fihlisoa lebopong
#
# La noka ea lefu
#
# U re nkele leholimong,
#
# Lefatšeng la heso!
#
# ----------------------------------------
#
# Lyrics for Jo, ke madimabe jwang:
# 1 Jo, ke madimabe jwang,
#
# Ke soto hakaakng!
#
# ke ya hlora , ha ke iketle,
#
# Jesu, ha o diketse.
#
# Ke tsamaya ke teneha,
#
# Dintho tsohle di bosula;
#
# Nkhauhele, Morena,
#
# Ke tsetselela wena.
#
# 2 Ke setse ke maketse
#
# Jo, ke tepeletse;
#
# Ha ke tsamaya ke le mong,
#
# Ke maswabi, ke dihlong.
#
# Na o kae, 'Moloki wa ka,
#
# Jesu, tsatsi la ho loka?
#
# Ho lefifi kahohle;
#
# Jesu, o nkhauhele!
#
# 3 o tabole lesira
#
# Oho, tlosa lera
#
# Le mpatelang wena, Jesu,
#
# Le mpakelng maruru,
#
# Ha ke ntse ke qhaqhasela,
#
# Ke shwele ke mohatsela,
#
# Oho, boya, nchabele,
#
# Nke ke bowele ke phele!
#
# 4 Na ke sa tla kopana
#
# Le wena, Morena,
#
# Ke o bohe sefahleho,
#
# Le 'na ke khore thabo?
#
# Ha o ntahla, ke khutsana,
#
# U ntshibolle, ke shwele,
#
# Jesu, ke o tshepile.
#
# ----------------------------------------
#
# Lyrics for Jo, khalefo ya Modimo:
# 12.8.12.8.D.
#
# 1. Jo, khalefo ya Modimo e befile,
#
# E benya, e thetheretsa!
#
# Jo, lehodimo le tuka ke bohale,
#
# Jo, sefefo sa ditlepetsa!
#
# Le tla tshabela kae, baetsadibe,
#
# Ha ho tshabeha hakana?
#
# O, tshabelang ho Jesu kapele:
#
# Jesu ke khotso ya rona.
#
# 2. Inamolohang, le lelale ka tshepo,
#
# Fefo se se se ya khutsa:
#
# Sefapanong, khohola tsa dithohako
#
# Di tsholoha, di phuthumetsa.
#
# Baetsadibe, le khobe matshwafo,
#
# Boning 'Moloki wa lona;
#
# Elang pelo, bohang seefapano:
#
# Jesu ke khotso ya rona.
#
# 3. Sefahleho sa Modimo se edile,
#
# 'Me se benya ke lerato.
#
# Le shoetswe ke Jesu, lona, le phedile:
#
# Ho lona ha ho sa le tsuo.
#
# Baetsadibe, thabang, le dumele;
#
# Ratang 'Moloki wa lona!
#
# Jesu, Mor'a Modimo sebele:
#
# Jesu ke khotso ya rona.
#
# 4. E, ka 'nete Jesu ke khotso ya rona;
#
# Taba tsohle di monate;
#
# Le ka hlaha khotla ka tshepo le lona,
#
# Modimo le ka 'mitsa Ntate.
#
# Baetsadibe, bana b topollo,
#
# Se lobeng letlotlo lena;
#
# Tumisang kahohle ka nyakallo:
#
# Jesu ke khotso ya rona.
#
# ----------------------------------------
#
# Lyrics for Jo, lefifi le lekaakang:
# 1. Jo, lefifi le lekaang,
#
# Le aparetseng lefatshe!
#
# Jo, botsho bo hlomodisang!
#
# Le tla chaba neng letsatsi?
#
# 2. Naledi e ntle ya meso,
#
# Hlaha, khaola lefifi!
#
# Re lebeletse ka tshepo
#
# Ho ela ha mechaedi.
#
# 3. Oho, tsatsi la ho loka,
#
# Ke nako, thuntsha mafube;
#
# Chaba fatsheng la Afrika,
#
# Fatshe la bomadimabe!
#
# 4. Hasa, hasa phatlalatsa
#
# Sedi la hao le molemo;
#
# Phatsima, benya, phaphama,
#
# Tsatsi le letle la Ntate!
#
# 5. Fedisa riti tse dihlong,
#
# Mekhwa, bosoro le madi;
#
# Ho lokolloe ba ditlamong,
#
# Baatho ba khotsheng maswabi!
#
# 6. diphahama di nyakalle
#
# Ke wena, Moathameleng;
#
# Le dikhohlo di binele
#
# Lesedi le di fihletseng!
#
# 7. Aparela ngalo tsohle
#
# Ka khanya le ka mohau;
#
# Kahohle ho utlwahale
#
# Thoko tsa 'Moloki Jesu.
#
# ----------------------------------------
#
# Lyrics for Jo 'na, lefifi le letso:
# 1. Jo 'na, lefifi le letsho,
#
# Pelong ho 'na le lekaakang,
#
# Le tsona riti tse kholo
#
# Tsa dintho tsee ke di ilang!
#
# 2. dipalla tsa Moren'a ka,
#
# Fahleho sa hae se setle,
#
# Di diketse mahlong a ka,
#
# Ke thibane le ditsebe.
#
# 3. Ke se ke utlwela hole,
#
# Jo, ke bonela leroothong;
#
# Le tumelo e timile,
#
# E itse lore ka pelong.
#
# 4. Leha e le hlasenyana,
#
# Hlase fela, ho lekane.
#
# Oho, tukisa tetema
#
# Pelong ya ka e serame.
#
# 5. Ka ntle ho 'na le kahare
#
# Ho apohe le lesoiti,
#
# Tumelo e be e khanye,
#
# E qhalanye le mehodi!
#
# 6. Nke ke bowele ke o bohe,
#
# Ke utloe Moathamela,
#
# Moren'a ka, ke tsamaee
#
# Ka tumelo le ka matla!
#
# ----------------------------------------
#
# Lyrics for Jo, sebe se sa hlakoheng:
# 1. Jesu o rapella sechaba
#
# Setulong sa bonamolo;
#
# Ya re mamelang ka ho thaba,
#
# Ya re kopelang bophelo;
#
# Mahodimong, ngalong ya khanya
#
# O nyolohetse ka hlolo;
#
# A bea madi a ho fenya
#
# Aletareng ya tefello.
#
# 2. Jesu o rapella phutheho:
#
# Rato la hae le lekaakang!
#
# O re batlela polokeho
#
# Ho Modimo o hloekileng.
#
# Ka matsoho a re hlabetsweng
#
# O re qobela dikotlo,
#
# Dikotlo tsee re di baketsweng
#
# Ke dibe le ke ditlolo.
#
# 3. Jesu o rapela ka mehla,
#
# O re rapella sedutse;
#
# Leha Satane a le matla.
#
# Khale Jesu a mo hlotse.
#
# Fatshe ha le ka re sokela,
#
# Leha sera se ka rora,
#
# Ha ho na'ng: Jesu wa rapela,
#
# Re leseng ho belaela.
#
# ----------------------------------------
#
# Lyrics for Jo, o batlile o dumela:
# 1. Jo, o batliule o dumela!
#
# U batlile o sokoloha:
#
# Empa wa leleka Moya wa Modimo,
#
# Wa re o tla baka ka mohlomong
#
# 2. Jo, o sa batla o dumela!
#
# Se dika-dike, wa timela.
#
# Jesu o nts'a kkopa: Ngwana, o mphe pelo.
#
# Bula hle, ke kene teng kajeno.
#
# 3. Jo, o batlile o dumela!
#
# Haufi-ufi, jo wa khutla!
#
# U batlile fela, ha ho thuse letho.
#
# Jwale ho fedile … ke timelo.
#
# ----------------------------------------
#
# Lyrics for Fatse le teng la nyakallo:
# 1 Fatše le teng la nyakallo,
#
# E leng la ba phelang;
#
# Fatše leo ke la pallo
#
# Ee re e thabelang;
#
# Ke moo bahloeki ba busang,
#
# Khanyeng e sa feteng,
#
# Hlohonolong le kholisang,
#
# Thabong e sa feleng.
#
# 2 Fatše leo ha le hole
#
# Moeli ke lefu;
#
# Etsoe batho re lerole,
#
# Le bocha ke sefi;
#
# Lefu, hape, ke monyako
#
# O isang ho lona
#
# Bana bohle ba topollo
#
# Ba kena ka oona
#
# 3 Ho tla  ba joang ha re fihla
#
# Khanyeng le monateng,
#
# Moo ho nyakallong ka mehla
#
# Ke bahloeki ba teng?
#
# Re tla leboha Molimo
#
# Bakeng sa topollo;
#
# Re tla rorisa le Jesu
#
# Le Moe'a bophelo
#
# ----------------------------------------
#
# Lyrics for Fatse lea feta, le ntse le hula:
# 11.10.11.10.D.
#
# 1 Fatše lea feta, le ntse le hula
#
# Lintšiu le lilemo tsa batho;
#
# Tsatsi ka leng le talima ho hola
#
# Ho re isang pel'a E moholo;
#
# Tsatsi ka leng le atemetsa ho tla
#
# Ha 'Moloki ea tlang ka kahlolo;
#
# Khale, khale a tsoatsoa a re batla
#
# E e-s'o be tsatsi la bofelo.
#
# 2 Fatše lee re le hatang ka maoto
#
# Le labella masapo a rona;
#
# Re tla ba re epele ho lona.
#
# 'Me re tla hlaha pel'a Molimo joang?
#
# E ka khona re itele pele.
#
# Oho, Jesu re tla itlhahisa ka'ng
#
# Ha re hloka tšoarelo ea libe?
#
# 3 U re lopolotse, 'me rea leboha
#
# U re atlehisetse lerato,
#
# Lerato ke tlamo ea ho phetheha,
#
# Re fe lona, etlaba ke phetho.
#
# U phakise ho tla busa lefatšeng,
#
# Ikhapele lipelo tsa bohle;
#
# Lentsoe la hao a le rongoe lichabeng,
#
# 'Muso oa hao o hlole kahohle.
#
# ----------------------------------------
#
# Lyrics for Fatseng la bomadimabe:
# 1. Fatsheng la bomadimabe,
#
# La ho hlomoha pelo,
#
# A re kholeng tse monate,
#
# Re khetheng tse bohloko.
#
# Ha letsatsi la kajeno
#
# Le chabile, le khanya,
#
# Re se belaelleng maru
#
# A ka hlahang hosasa!
#
# A re jaleleng ba bang
#
# Tsa mosa, tsa molemo,
#
# Tsa khotso e ahisang,
#
# Le tsa lehlohonolo!
#
# 2. Re se keng ra belaela
#
# Ha re na le tsietsi;
#
# Leha di re bokanela,
#
# Di le kaa ka dinotshi;
#
# Haholo re di lemoheng
#
# Tse monate le tsona,
#
# Tsee Ntate ya re ratileng
#
# A re sitsang ka tsona!
#
# A re jaleleng ba bang,…
#
# 3. Che, hase meutlwa fela,
#
# Le ditshehlo tse hlabang,
#
# Tse mpe, tse hlokofatsang,
#
# Tse ntseng di thiba tsela;
#
# Palesa le tsona di teng,
#
# Tholwana tse hlabosang,
#
# Tsa thabo e phethehileng,
#
# Tsa khotso e khodisang,
#
# A re jaleleng ba bang,…
#
# 4. A, ka 'nete, borapedi
#
# Le ho kholwa ha pelo
#
# Di etsa motho morui
#
# Le har'a tse bohloko.
#
# Leha ntshi di le moekho,
#
# Thabo e ntse e kola;
#
# Kantle ke ntwa, ke meleko,
#
# Kahare: khotso fela.
#
# A re jaleleng ba bang,…
#
# 5. Ke atetswe ke ditshitso,
#
# Di mela tseleng ya ka;
#
# Ke di boha ka makalo,
#
# Ke sitwa ho di bala.
#
# Ke o ake hle letsoho,
#
# O Rare, wa mpaballa
#
# Leha ke fellwa ke puo,
#
# Ahe, hle, ke ya boka!
#
# A re jaleleng ba bang,…
#
# ----------------------------------------
#
# Lyrics for Bokang, bokang Moloki:
# 1. Bokang, bokang 'Moloki wa rona, Jesu,
#
# Rato la hae, tlong, le le tumiseng.
#
# Mahodimong, mafatsheng e be sehou
#
# Se mo bokang, sa pelo di le ding!
#
# O molemo, o lerato hakaakang!
#
# O boloka bohle bam o tshepang.
#
# Amohelang dithoko tsa mangeloi,
#
# Ho mo tlotlisa, Jesu 'Moloki!
#
# 2. Bokang, bokang 'Moloki wa rona Jesu,
#
# Ke konyana e hlabetsweng rona.
#
# Sefapanong, ka madi a hae le lefu,
#
# O phetile topollo ya rona.
#
# Molahluwa ya neng a khotshe dihlong,
#
# Jwale ke Morena lehodimong.
#
# 'Mokeng, 'mokeng! Ke tshepo, thabo ya rona,
#
# Sehlabelo, 'Moloki, Morena.
#
# 3. Bokang, bokang 'Moloki wa rona, Jesu,
#
# Le tumiseng mohale ya fentseng!
#
# Ka lebitleng o hlotse matla a lefu,
#
# A nyedisa bo-Satane pontsheng.
#
# O n'a shwele, jwale ke ya phedileng,
#
# 'Me o phela ka mehla le mehleng.
#
# 'Mokeng, 'mokeng, lona, bana ba topollo,
#
# Mo tumiseng hohle ka nyakallo!
#
# 4. Bokang, bokang 'Moloki wa rona, Jesu,
#
# Mahodimong, hlamohang ka thabo!
#
# Ke Morena, boning 'Moloki wa batho;
#
# Duluetsang, binang ka nyakallo!
#
# Mangeloi, emang matlotlosiea,
#
# Ha le boha Morena wa khanya;
#
# Le re tlatseng, re mo fapheng ka dithoko,
#
# Molopoldi, Mora wa Modimo.
#
# ----------------------------------------
#
# Lyrics for Fatseng lena hase hae ha eso:
# 1. Fatsheng lena hase hae ha eso;
#
# Che, ha ho na'ng; che, ha ho na'ng.
#
# Leha Ntate a re; Bea pelo,
#
# Che, ha ho na'ng; che, ha ho na'ng.
#
# Athe mona dillo di atile,
#
# Empa Jesu o nts'a mpolokile;
#
# Ke re, jwale le ka mehla eohle,
#
# O nts'a le teng, o nts'a a le teng.
#
# 2. Mona ke phela ke se na matla;
#
# Ho jwalo ke'ng, ho jwalo ke'ng?
#
# Jesu eena ke 'Moloki wa ka;
#
# O nts'a le teng, o nts'a a le teng.
#
# Ha ke wela o ntsosa ka mosa,
#
# Ha ke fosa o nkisa ka tsela;
#
# Ha kefokola o nts'a mpha matla;
#
# O nts'a le teng, o nts'a a le teng.
#
# 3. Fatsheng lena ke ntse ke hloriswa;
#
# Ha ho na'ng teng, ha ho na'ng teng.
#
# Ba ha Ntate ba tsejwa ke hona;
#
# Ho ntse ho ntoketse le teng.
#
# Motse ola o keno aka thata,
#
# Hape o keno aka mahlomola;
#
# Jesu, ke ntse ke nyatsetswa wena;
#
# O nts'a le teng, o nts'a a le teng.
#
# 4. Ke bona lefu ho atamela;
#
# Le teng ke teng, le teng ke teng.
#
# Nke ke ka tshaba botsho jwa lona,
#
# Etswe Jesu o nts'a le teng.
#
# Leha nka hlaha khotla, ha Jesu,
#
# O tla re ke hloka le molato;
#
# Ke ya kena 'musong ka bosweo.
#
# Hona ke teng, hona teng.
#
# ----------------------------------------
#
# Lyrics for Ka dinako tsohle:
# 1. Ka dinako tsohle,
#
# Moren'a ka,
#
# Oho, o nkhopole,
#
# ke ya rapela.
#
# E, ka metsotso eohle,
#
# Jesu, ke ya o hloka;
#
# O, ke o hlolohetswe,
#
# Bapa le 'na.
#
# 2. Ka dinako tsohle
#
# Bua le 'na;
#
# Khotso ya sebele
#
# U mphe eona.
#
# E, ka metsotso eohle, …
#
# 3. Ka dinako tsohle
#
# E-ba haufi;
#
# Melekong se ntahle,
#
# Ka ba 'notshi.
#
# E, ka metsotso eohle, …
#
# 4. Ka dinako tsohle
#
# Thabong, dillong,
#
# Tlo, hlola o dule
#
# Ho 'na pelong.
#
# E, ka metsotso eohle, …
#
# 5. Ka dinako tsohle
#
# Oho, nthute,
#
# Ke tle ke o khahle
#
# Ka tsa 'nete!
#
# E, ka metsotso eohle, …
#
# 6. Ka dinako tsohle
#
# U be wa ka,
#
# Ke be wa hao jwale,
#
# Le ka mehla.
#
# E, ka metsotso eohle, …
#
# ----------------------------------------
#
# Lyrics for Ka hlahlathela feelleng:
# 1 Ka hlahlathela feelleng halelele,
#
# Ke sa na modimo, ke se na tshepo;
#
# Ho le lefifi, nyora le nkhamile,
#
# Ke tsietswe, ke shwele ke sekoboto.
#
# Jwale ke bone sediba sa 'nete,
#
# Sediba se maphodi, se monate.
#
# 2 Har'a dikaka tsa dibataolo
#
# Ka 'na ka cheka, ka hlora hakaakang!
#
# Ke batla metsi, empa ho se letho.
#
# Jo, ke lehlabathe fela le monyelang!
#
# Jwale, ke bone sediba sa 'nete…
#
# 3 Makhatheng a ho shwa, ka utlwa lentswe
#
# Le re: wena ya nyorileng tlo metseng!
#
# Ha ke tadima, ka bona moroeroe:
#
# Ke Jesu! A mpitsa a eme sedibeng.
#
# Jwale, ke bone sediba sa nete…
#
# 4 Ahe, ke ya o boka, Jesu wa ka,
#
# Ke le madibeng a mahlohonolo!
#
# Ke hlaphohile, ke tsoha molota;
#
# Kajeno ke ruile khotso, nyakallo.
#
# Jwale, ke bone sediba sa 'nete…
#
# ----------------------------------------
#
# Lyrics for Ho re chabetse kajeno:
# 1.	Kajeno, ho nchabetse
#
# Letsatsi le letle;
#
# Khale ke le lebeletse,
#
# Joale le hlahile.
#
# U nkamohele, Morena;
#
# Le lona, phutheho;
#
# Ke tli'o kena ho  lona,
#
# Ke kopa litulo.
#
# 2.	U 'nile ua mpaballa
#
# Bocheng bohle ba ka,
#
# Ho fihlela tsatsi lena
#
# Ke phelang ka lona;
#
# Ho 'na e nts'e le mohlolo
#
# U bone eng ho 'na?
#
# Ha ke neoa lehlohonolo
#
# La ho ema mona
#
# 3.	Ha ke ema, Morena
#
# Ho bolela tsa hao,
#
# Ke re, u nolo, u mosa,
#
# U na le lereko;
#
# Pelo ea hao e mohau,
#
# Hape e telele;
#
# Ruri, ha u rate lefu
#
# La baetsalibe.
#
# 4.	U ntatile timelong
#
# Moo ke neng ke shoele
#
# Libeng tsohle le melatong,
#
# Matleng a lihele.
#
# Kajeno u ntšokolotse,
#
# U ntšwaretse libe,
#
# U bile u 'nchafalitse
#
# Ka Moea oa 'nete.
#
# 5.	Kea itlama, Morena,
#
# 'Na, ngoan'a hao joale;
#
# Ke oa ntlo ea hao kajeno,
#
# Ke eena ka 'nete;
#
# Ke be eena ka ho rata
#
# Litaelo tsa hao,
#
# Ke be eena ka ho etsa
#
# Mosebetse oa hao.
#
# 6.	Kea itlama, Morena,
#
# 'Na, ngoan'a hao joale,
#
# Ke oa ntlo ea hao kajeno,
#
# Ke eena ka 'nete;
#
# Ke be eena ka ho hana
#
# Litšila le libe,
#
# Ke be eena ka ho lahla
#
# Mekhoa ea lefatše.
#
# ----------------------------------------
#
# Lyrics for Kajeno, ngoan'abo rona:
# 1 Kajeno, ngoan'abo rona
#
# O re siea lillong;
#
# O faletse fatšeng lena,
#
# Ho ea leholimong
#
# 2 Ho lla, che , hoa re lokela,
#
# Empa tšepo e teng;
#
# O kene hae, o phomola
#
# Thabong e sa feleng.
#
# 3 Oho, pel'a bitla lena
#
# Hlakolang meokho!
#
# Ha le letšo, lea khanya,
#
# Ke motho ea phelang.
#
# 4 Se lleng ! Le se re, ke mofu
#
# Eo re 'molokang.
#
# Bonang, Moreneng, ha Jesu,
#
# Ke ntlo ea bophelo.
#
# 5 E, oa phela, o hlobotse
#
# Tse mpe, tse bohloko;
#
# Jesu o mo khabisitse
#
# Ka khanya e kholo.
#
# 6 Se reng lefu le ka khaola
#
# Tlamo tsa lerato;
#
# Le re hulela ka matla
#
# Motseng oa bophelo.
#
# 7 Se lleng! Mahlo a tumelo
#
# Se a tutubatseng!
#
# Le haufi leholimo,
#
# Re ea kopana teng!
#
# ----------------------------------------
#
# Lyrics for Kajeno re rorisa:
# 7.7.8.7.7.8.
#
# 1 Kajeno re rorisa
#
# Morena oa marena, bis
#
# Ke eena 'Mopi oa batho
#
# Leha re senyehile, bis
#
# Jesu o re ratile,
#
# O re lefetse melato.
#
# 2  Ba leng lehlohonolo
#
# Ke ba pelo e nolo, bis
#
# Ba khumamelang Morena.
#
# A re atameleng, bis
#
# Bohle re mo thabeleng,
#
# Mong 'a khabane ke eena
#
# 3  A re mo sebeletseng
#
# Ka pelo tse tšohileng, bis
#
# Ka tiisetso le ka bottle.
#
# Re lumeleng litaba. Bis
#
# Tse rongoang ke jehova
#
# Ho baetsalibe bohle.
#
# 4 Ba natlang leholimo,
#
# Ba tla bona Molimo bis
#
# Ka letlotlong le leseling;
#
# Ba seng bam o lumetse bis
#
# Ba se ba amohetse
#
# Hlohonolo le sa feleng.
#
# ----------------------------------------
#
# Lyrics for Kajeno re tlil'o llela:
# 1. Kajeno re tlil'o llela
#
# Ngoan'eso ea shoeleng,
#
# Ea qalileng ho iketla
#
# Botleng bo sa feleng.
#
# 2. Na bophelo ba rona ke'ng?
#
# Re heloa kapele;
#
# Re se re boela leroleng,
#
# Moo ho bolang 'mele.
#
# 3. Jehova ea re bopileng
#
# O re file moea,
#
# e leng moea o sa feleng,
#
# O phelang ka mehla.
#
# 4. Ho shoa re ho hlahisitse
#
# Ka libe tsa rona;
#
# Bophelo bo bonahetse
#
# Lefung la Morena.
#
# 5. Ruri bitla le tšabeha
#
# Ho ba sa lumelang;
#
# Leholimo le rateha
#
# Ho ba leng ho kreste.
#
# 6. A re fetoheng kaofela,
#
# Re ineeleng Jesu;
#
# Re tle re phele ka eena,
#
# Mohloli oa lefu.
#
# ----------------------------------------
#
# Lyrics for Ka lipelo tse monate:
# 1 Ka lipelo tse monate,
#
# Re roriseng Molimo Ntate,
#
# Le bana bohle ba oona;
#
# Re leboheng reko la hae,
#
# Mosa le mohau o sa eeng kae;
#
# A tumisoe har'a rona
#
# Ho bokoe Morena
#
# Ka letsatsi lena
#
# Balumeli,
#
# Re mameleng,
#
# Re lumeleng
#
# Lentsoe la 'mopi oa rona.
#
# 2 Leseli la hao le khanye,
#
# 'Me lentsoe le re bonesetse
#
# Ka Moea o halalelang.
#
# 'Nete tsa hao, tsa bophelo,
#
# Li amoheloe ka tumelo
#
# Pelong tse u chesehelang.
#
# Tumelong ea 'nete
#
# Re fihlele khotso
#
# Re tlotlise
#
# Bitso la hao,
#
# Mong 'a mohau,
#
# Ka tsohle tsee re li etsang.
#
# ----------------------------------------
#
# Lyrics for Ka mali a hao a matle:
# 8.7.8.7.
#
# 1 Ka mali a hao a matle,
#
# Le reko la hao, Jesu,
#
# Ke fuoa ka nako tsohle
#
# Pelo e ntle, e tšoeu.
#
# 2 Se mpolelleng hle, baena,
#
# Menyaka ea lefatše;
#
# Ea leng lintho tšohle ho 'na
#
# Ke Jesu, een'a 'notši.
#
# 3 Ha ke ne ke sa mo tsebe,
#
# Ke ne ke ntse ke hlora
#
# E thata joko ea sebe,
#
# Ee ke neng ke e jara
#
# 4 Ke ne ke ntse ke phallela
#
# Litoro tse 'nyamellang,
#
# Ha ke ne ke se na eena,
#
# Jo, ke ne ke phela joang?
#
# 5 Jesu, ha ke u fumane,
#
# Na ke sa tla ea ho mong?
#
# Maotong a hao ke bone
#
# Tsohle tse ka nkholisang
#
# 6 Ke ne ke tla khathetse,
#
# Ke tsamaea ka lillo,
#
# Empa u s'u nkhatholotse
#
# Lilibeng tsa nyakallo.
#
# ----------------------------------------
#
# Lyrics for Ka re ke tla iponela:
# 1. Ka re, ke tla iponela,
#
# Ke se ke k aba ka thella,
#
# Ke eme, ke tiee matla;
#
# Jo, e s'e le ha ke wela.
#
# 2. Ke madimabe hakaakang!
#
# Na hloho see se tshabehang
#
# Se kile sa ntlhahela jwang?
#
# Jo, maswabi a makatsang!
#
# 3. Ke hole sa hao, Morena,
#
# Ke seritsa saka mehla;
#
# Ke hloya see ke leng sona,
#
# Ke tshaba le ho ipona.
#
# 4. O, 'Moloki wa ka, Jesu,
#
# Mohla o mphemisang lefu,
#
# U 'nchafaletse le pelo.
#
# E ne e le ka mohau.
#
# 5. Ke tenwa ke ho rapela,
#
# Ho fadimehagwantlhola;
#
# E sa le mohau fela,
#
# Oo nka o tshepang ka mehla.
#
# 6. Ke ngwana ya mefokolo
#
# Oho, totisa tumelo,
#
# Wena, Jesu ya lerato,
#
# tshepo ya ka le nyakallo.
#
# ----------------------------------------
#
# Lyrics for Baratuwa ba Jesu:
# 1 Baratuwa ba Jesu, le duletse'ng fela?
#
# Bonang,meriti e se e namile;
#
# Haufi letsatsi le se l'ea dikela;
#
# Le dudutse'ng fela letsatsi lohle?
#
# Lefatshe lohle ke tshimo eso,
#
# Mabele a s'a le matsho.
#
# Bakotudi, se tswafeng,
#
# Kenang mosebetsing,
#
# le ya bitswa kajeno.
#
# 2 Kenang ka potlako, e s'e le bosiu,
#
# Nako ya re feta, re se re rakwa;
#
# Re itlhahaneleng, re qhitse khororo.
#
# Oho, re khothaleng, morena wat la.
#
# Lefatshe lohle ke tshimo eso…
#
# 3 Batlang fatsheng lohle bakhethwa ba Jesu,
#
# Le qete dinaha, metse, metsana;
#
# Le bitse ba bacha, bana, le maqheku;
#
# tshimong ya morena bang ditema.
#
# Lefatshe lohle ke tshimo eso…
#
# 4 Baromuwa ba bang ba tshetse mawatle,
#
# Ba tsoma mafatshe,dihlekehleke;
#
# dipheletsong tsohle ba se ba fihlile,
#
# tshimo ya morena ba se ba e dikile,
#
# Lefatshe lohle ke tshimo eso…
#
# 5 Le lona kajeno le hlobohe botswa,
#
# Kenang le kotule, khwahlapisisang,
#
# Marena, bafo,le bona ba basehla,
#
# Bohle ke diqwapi tse qenehelwang.
#
# Lefatshe lohle ke tshimo eso…
#
# 6 Bonang hle mabele a se a senyeha,
#
# A hloka matsoho a bakotudi;
#
# Rapelang morena, a rome dinatla,
#
# Batho ba sebele le dikhothadi.
#
# Lefatshe lohle ke tshimo eso…
#
# ----------------------------------------
#
# Lyrics for ke ya leboha, Modimo:
# 1 ke ya leboha, Modimo,
#
# Dintle tsa letsatsi lena:
#
# U mpolokile bophelong
#
# U ntlositse le melekong.
#
# 2 o ntise le ka bosiu,
#
# U nthobatse ka leseho;
#
# Rato la hao le nkapese,
#
# Matl'a hao a ntshireletse!
#
# 3 Ak'u ntshwarele, ka Jesu,
#
# Dibe tsa ka tsa kajeno,
#
# Tsa ketso le tsa takatso,
#
# Ke ithoballe ka khotso.
#
# 4 Ke phomole fubeng sa hao ,
#
# Ke bolokwe ka mohau,
#
# Ke be ke tsohe ka matla
#
# Ho o leboha ka mehla.
#
# 5 Letsatsi le sa phirimeng
#
# Na le tla nchabela neneng,
#
# Ke tle ke fihle phomolong,
#
# Ho baiketli, letlotlong?
#
# ----------------------------------------
#
# Lyrics for Kea leboha, Molimo:
# 1 Kea leboha, Molimo,
#
# Lintle tsa letsatsi lena:
#
# U mpolokile bophelong
#
# U ntlositse le melekong.
#
# 2 U ntise le ka bosiu,
#
# U nthobatse ka leseho;
#
# Rato la hao le nkapese,
#
# Matl'a hao a ntšireletse!
#
# 3 Ak'u ntšoarele, ka Jesu,
#
# Libe tsa ka tsa kajeno,
#
# Tsa ketso le tsa takatso,
#
# Ke ithoballe ka khotso.
#
# 4 Ke phomole fubeng sa hao ,
#
# Ke bolokoe ka mohau,
#
# Ke be ke tsohe ka matla
#
# Ho u leboha ka mehla.
#
# 5 Letsatsi le sa phirimeng
#
# Na le tla nchabela neneng,
#
# Ke tle ke fihle phomolong,
#
# Ho baiketli, letlotlong?
#
# ----------------------------------------
#
# Lyrics for Ke bidiba bo bilohang:
# 8.8.8.8.8.8.
#
# 1 Ke bodiba bo bilohang,
#
# Ke koetsa ya mahlomola;
#
# Ke phororo tse nkhoholang,
#
# Ke hlotswe, ke ya timela.
#
# Jesu, ke leba ho wena,
#
# Oho o mpoloke le 'na!
#
# 2 Bohlale le ho itshepa,
#
# Ka re ke sona sehlare.
#
# Jo, ke mahohodi fela,
#
# ke ya kukwa, ke ya teba!
#
# Jesu ke leba ho wena…
#
# 3 Ka tshepana le dinatla,
#
# Ka itshwarella ka tsona;
#
# Ke qhoboi, ya fothoha,
#
# Ke sentse ke tsieleha.
#
# Jesu, ke leba ho wena…
#
# 4 Jesu, ke wena o le mong
#
# Sehlare sa 'nete sa ka;
#
# Fika le emeng phororong,
#
# Ke itshwarella ka wena.
#
# Jesu, ke leba ho wena…
#
# 5 Umphalletse, se ntlohele,
#
# Nkukele sefubeng sa hao;
#
# Ha fefo di le bohale,
#
# Ho 'na a tla 'n'e be khotso.
#
# Jesu, ke leba ho wena…
#
# ----------------------------------------
#
# Lyrics for Ke boloketsoe phomolo:
# 1Ke boloketsoe phomolo
#
# Mehahong e sa feleng
#
# E seng ka pheello ea ka,
#
# Ke Jesu ea mpatletseng.
#
# Re tla be re khatholohe,
#
# Motse re 'ne re o bohe
#
# Le Jesu re mo lebohe
#
# Phomolong ena
#
# 2 Ke tla iketla hakaakang,
#
# Mehahong e sa feleng;
#
# Ke tla ja le tse hlabosang,
#
# Ha ke sa tla tloha teng.
#
# Re tla be re khatholohe,…
#
# 3 Ha Ntate, hae, ho hloekile,
#
# Ho hanana le tšila;
#
# Ho hlophiloe, ho hloekile,
#
# Ho loketse ba khanyang.
#
# Re tla be re khatholohe,…
#
# 4 Ke tla bonana le Jesu;
#
# A le teroneng ea hae;
#
# Ke mo tlotle le baheso,
#
# Ka mehla e sa eeng kae!
#
# Re tla be re khatholohe
#
# ----------------------------------------
#
# Lyrics for Ke bone hape lesedi:
# 1 Ke bone hape leseli,
#
# Seli le letle la letsatsi;
#
# Le romiloe ke Monghali,
#
# Ho thabisa lefatše,
#
# 2 U ntsamaise, Morena,
#
# Ka tsatsi lena u mpoloke;
#
# Ha ke sa bitsa ho uena. (bis)
#
# U ntemose, ke loke!
#
# ----------------------------------------
#
# Lyrics for Ke bone hape lesedi:
# 1 Ke bone hape lesedi,
#
# Sedi le letle la letsatsi;
#
# Le romilwe ke Monghadi,
#
# Ho thabisa lefatshe,
#
# 2 o ntsamaise, Morena,
#
# Ka tsatsi lena o mpoloke;
#
# Ha ke sa bitsa ho wena. (bis)
#
# U ntemose, ke loke!
#
# ----------------------------------------
#
# Lyrics for Ke bone, ke bone tsela:
# 1. Ke bone, ke bone tsela,
#
# Moo ke fumaneng phomolo;
#
# Ke khotso ya pelo fela
#
# Ho Jesu, mong'a topoolo.
#
# O , thaka tsa me tse hlorang,
#
# A re tshepeng eena fela;
#
# O thus aba mo rapelang;
#
# Ke 'Moloki wa ka mehla.
#
# 2. Madi a hae a hlakotse
#
# Dibe tsa rona Golgotha;
#
# Le jwale o re sietse
#
# Moe'a hae ho re hloekisa.
#
# Satane o re befetse,
#
# A ka 'na a re sokela,
#
# Jesu eena o mo hlotse;
#
# Ke 'Moloki wa ka mehla.
#
# 3. Khale ka ya ke hlabana,
#
# Ke le lefifing, matswalong;
#
# Jesu, ke ne ke lekanya,
#
# Ke ya bolokang mohlomong.
#
# Empa sedi le nchabetse,
#
# Hang maswabi a apoha;
#
# Jwale, ke ;mone, ke khotshe;
#
# Ke 'Moloki wa ka mehla.
#
# 4. O, Jesu, lesedi la ka,
#
# Thebe ya me le nyakallo,
#
# Jesu, ke tla o latela
#
# Hohle tseleng ya bophelo.
#
# Tsietsing dife le dife,
#
# Ke tshepa, ke boka wena;
#
# Ho pheleng le ho shoeng; hohle
#
# U 'Moloki wa ka mehla.
#
# ----------------------------------------
#
# Lyrics for Ke bonela leholimo:
# 8.4.8.4.8.4.
#
# 1 Ke bonela leholimo –  Mane hole,
#
# Ke le bona ka lerootho, – Ho fifetse;
#
# Na ke tla fihla monyako- O s'o koetsoe?
#
# 2 Ke bonela khalalelo- Mane hole;
#
# Hha e le moo mefokolo –  E sa tlohe,
#
# Teng na nka fihla, 'na motho –  Ea leng mobe?
#
# 3 Hape, ke bonela thabo –  Mane hole;
#
# Mona ke masoabi, lillo –  Ha li fele;
#
# E le lefa le bohloko –  La balibe.
#
# 4 Ke bonela leholimo –  Mane hole;
#
# Mona ho le matšoenyeho –  le marole
#
# A lintoa le a meleko –  Ea lefatše.
#
# 5 'Melaeli, lintho tseo –  Na li hole;
#
# Ha u ka shoa u lumela –  Ka sebele,
#
# Hang –  hang, Jesu o tla u fa –  Tsona Tsohle.
#
# ----------------------------------------
#
# Lyrics for Ke buletswe phatlalatsa:
# 1. Ke buletswe phatlalatsa
#
# Khoro ya lehodimo!
#
# Sefapano se nchabela
#
# Ka khanya ya lerato.
#
# O mokaakang mohau ona
#
# Khoro e buletswe le 'na,
#
# Le 'na, le 'na.
#
# E buletswe le 'na.
#
# 2. Barui bafumanehi,
#
# Le bafo, le marena
#
# Bohle ba batlang 'Moloki,
#
# Le buletswe le lona.
#
# O mokaakang mohau ona, …
#
# 3. Ha ho mofuta le o mong,
#
# Ha ho motho ya kheswang.
#
# Bohle, kenang lehodimong,
#
# Leha le ka ba mang, mang!
#
# O mokaakang mohau ona, …
#
# 4. Itlhahaneleng ka matla
#
# Ha khoro e sa butswe;
#
# Ha ho kenoe ka liphera
#
# Ha ho setse ho koetswe
#
# O mokaakang mohau ona, …
#
# ----------------------------------------
#
# Lyrics for Ke fumane bofihla:
# 1 Ke fumane bofihla
#
# Bo sieo lefatsheng;
#
# Ke thabo ya ka mehla,
#
# Khotso e sa feteng.
#
# Leha dillo di le teng,
#
# Le dipelaelo.
#
# Ke motho ya thabileng,
#
# Ke sa na le khotso.
#
# Ke thabo fela
#
# Ka pelong ya ka.
#
# Ke thabo fela
#
# Ka pelong ya ka,
#
# Ke thabo fela.
#
# 2 Leha ke le maswabing,
#
# Ha ke le bodutu,
#
# Ha ke ya lahlehileng,
#
# Ke san a le Jesu.
#
# Ke eena ya ntshedisang
#
# Ka rato la 'nete;
#
# Ke eena ya mpuisang
#
# Hamonate-nate.
#
# Ke thabo fela…
#
# 3 E, ke tsebile mara,
#
# Sediba se babang;
#
# Ka tliswa teng, ka noeswa
#
# Hangata hakaakang!
#
# Ha ke seka meokho,
#
# Ke nwa ka bohloko,
#
# Ka tutubollwa mahlo,
#
# Ka fumana Jesu.
#
# Ke thabo fela…
#
# 4 Hang metsi a phekolwa,
#
# 'Me a ba monate
#
# Ha ke noeswa ke eena,
#
# Moren'a ka, ntate.
#
# Ka itlhakola dillo,
#
# Ke dihlong ho bua,
#
# Ka mo aka letsoho,
#
# Fuba sa phatloha.
#
# Ke thabo fela…
#
# 5 Jesu, hase le botle!
#
# Ha ke le ho wena,
#
# Meriting o phodileng,
#
# ke ya khatholoha.
#
# Didibeng tsa lerato,
#
# Tse kollang ka mehla,
#
# Ke ikhella nyakallo,
#
# Le khotso le matla.
#
# Ke thabo fela…
#
# ----------------------------------------
#
# Lyrics for Ba kae, ba kae bakotudi:
# 1 ba kae, ba kae bakotudi
#
# Har'a lona, badumedi?
#
# Kenang tshimong ya morena,
#
# Tlong, le kotule le lona.
#
# Mabele a butsoitse,
#
# A bile a oetse fatshe.
#
# Oho, nako ya feta!
#
# Mafupu a tswale ditha!
#
# ya khanyang, leha a le mong,
#
# Ho batho ba lahlehileng.
#
# Ke naledi lehodimong,
#
# E khanyang, e sa dikeleng.
#
# 2 O, potlakang badumedi,
#
# Leha le se bakotudi;
#
# Leha le re le fokotse,
#
# Kenang, hle, le khwahlapise.
#
# Inamang le thonake
#
# diqwapi, e 'ngoe le 'ngoe.
#
# Ha le hloka lefupu,
#
# Le ka thonaka dihlaku.
#
# ya khanyang, leha a le mong…
#
# 3 Bonang, ke lepotla-potla
#
# Ha morena a laela;
#
# Hohle bana ba modimo
#
# Ba tsoile, ba tseka tshimo.
#
# Ha Jesu a hlahloba
#
# Mabele a hae dihlaba,
#
# 'Me teng le hloka dihlaku,
#
# Jo, ho tla ba jwang, ba heso
#
# ya khanyang, leha a le mong…
#
# 4 Bonang, tsatsi le sa le teng,
#
# Kenang, kenang mosebetseng;
#
# Batlang batho ka pheello,
#
# Le ba khanne ka cheseho,
#
# Ha le ntse le iketla,
#
# Jo, badibe ba timela!
#
# Ba baholo la bana
#
# Ke mabele a morena.
#
# ya khanyang, leha a le mong…
#
# ----------------------------------------
#
# Lyrics for Ke Golgotha:
# Ke Golgotha, ke Gethsemane,
#
# Ke serapa sa mehlwaare,
#
# Moo ke 'neng ke ee ke fumane
#
# Tse ntlhomolang pelo ruri.
#
# Ke bona mang serapeng sena,
#
# A oetse fatshe ka dillo,
#
# A qetwa ke mefehelo?
#
# Ke pheko ya dibe tsa rona,
#
# Mo-jara-melato
#
# Ya rapellang batho.
#
# Jesu, Jesu, nkhauhele,
#
# Le 'na tl'u nthapelle! (bis)
#
# ----------------------------------------
#
# Lyrics for Ke habile leholimong:
# 1 Ke habile leholimong,
#
# Tseleng ha ke na bolutu;
#
# Ha ke tsamaee ke le mong,
#
# Ke na le Morena Jesu.
#
# 2 Lefelleng moo ke tsamaeang,
#
# Ho lahleha ba bangata;
#
# Empa 'na, ea ntsamaisang
#
# Ke Jesu, ke mong a' tsela.
#
# 3 Ha ke tsebe pelaelo,
#
# Tlala le ho tšera pelo;
#
# Che, ke ntse ke khora thabo,
#
# Ha ke ntse ken a le Jesu.
#
# 4 o, ho monate hakaakang
#
# Ha ke buisoa ke Jesu!
#
# O tseba ho felisa hang
#
# Tsohle tse nkhathatsang pelo.
#
# 5 Mohlomong, tsela e ntenne,
#
# Ke shoele ke mokhathala;
#
# Jesu o teng, ho ntekane,
#
# Oa nkhothatsa, o mpha matla
#
# 6 ke habile leholimong,
#
# Ke ea ka mafololofolo;
#
# Ha ke sa lakatsa ho hong
#
# Ha ke tsamaea le Jesu.
#
# ----------------------------------------
#
# Lyrics for Ke itella wena:
# 1 ke itella wena,
#
# K'wena ke o shoetseng;
#
# Ke ka madi a ka
#
# Khale ke o lopolotseng.
#
# E, ke iteletse wena:
#
# Na le wena wa nthata na?
#
# 2 E, ka o hlorela,
#
# Ka ba mahlomoleng,
#
# Ho iketle wena,
#
# U phele ka ho sa feleng.
#
# E, ka o hlorela wena;
#
# Na le wena wa nthata na?
#
# 3 Ke tsoile leseding,
#
# Tulong tsa borena,
#
# Ke tlile lefifing
#
# Ke 'notshi ho batla wena.
#
# E, ke pheeletse wena;
#
# Na, le wena, wa nthata na?
#
# 4 Ke tlisetsa wena
#
# Dimpho tse molemo
#
# Tsa ho o phadisa.
#
# Khotso, thabo, le topollo,
#
# Ke di tliseditse wena;
#
# Na, le wena wa nthata na?
#
# 5 o ikabele 'na
#
# Ho shwa le ho phela;
#
# U ntelle bowena,
#
# U be wa ka, wa ka fela.
#
# Oho, o be wa fela
#
# Ha o re wa nthata le 'na!
#
# ----------------------------------------
#
# Lyrics for Ke lehlahana fela:
# 1. Ke lehlahana fela la Morena,
#
# Ke mo latela hohle moo a yang.
#
# Ke mametse taelo ho eena,
#
# Ke mo tsetse pelo, ke ya nkhodisang.
#
# O, utlwang taelo: Pele-pele!
#
# Lona le ma-lala-a-laotswe.
#
# Le 'na ke tla phalla, ke tshwaele,
#
# Leha ke le lehlahana fela.
#
# 2. Ke lehlahana fela la Morena;
#
# Dibetsa tsa hae o mphile tsona.
#
# Wa ntshireletsa, o nts'a nqobela.
#
# Marumo a nkwelang a kuba fela.
#
# O, utlwang taelo…
#
# 3. Ke lehlahana fela la Morena,
#
# Ha ho e mong, ke eena mohale;
#
# O tsoile, o lwanne monaila,
#
# Dira pel'a hae di qhemetsehile.
#
# O, utlwang taelo…
#
# 4. Ke lehlahana fela la Morena;
#
# Kajeno ha ke mo latela ntoeng,
#
# ke ya qatedisa, ho fentse eena;
#
# Ke ya orohela le eena khanyeng.
#
# O, utlwang taelo…
#
# 5. Ke lehlahana fela la Morena;
#
# Ke tla kena le eena phomolong;
#
# Le 'na ke be teng ha bam o roka,
#
# E, le 'na ke mo faphe lehodimong.
#
# O, utlwang taelo…
#
# ----------------------------------------
#
# Lyrics for Ke mahlaku fela-fela:
# 8.6.8.D.
#
# 1 Ke mahlaku fela-fela,
#
# Le ho tshera pelo;
#
# Ho se ho fedile matla,
#
# Se setseng ke mo khathala.
#
# Kotulo kajeno.
#
# 2 Ke mahlaku fela-fela.
#
# Na di kae dinako?
#
# Di koenehetswe kaofela,
#
# Cheseho ya ba ya tima;
#
# Kajeno kotulo
#
# Ke mahlaku fela-fela.
#
# 3 Ke mahlaku fela-fela,
#
# Jo, mabele h'a eo;
#
# Puo di tswetse mofoka,
#
# Ketso le tsona lehola.
#
# 'Me jwale kotulo
#
# Ke ditlhaka fela-fela.
#
# 4 Ke mahlaku fela-fela.
#
# Ha ho le tebalo
#
# E ka fedisang ditaba
#
# Tse jang pelo; dia sala
#
# 'Mejwale kotulo
#
# Ke mahlaku fela-fela.
#
# 5 Ha o ririetsa fela
#
# Mahlaku a ponneng,
#
# Hleka o Ka thotha 'ona,
#
# Yaba o re ho morena;
#
# See ke se kotutseng
#
# Ke mahlaku fela-fela.
#
# ----------------------------------------
#
# Lyrics for Ke mang, ke mang:
# 1 Ke mang, ke mang mo monyako,
#
# Ya kokotang hakalo?
#
# Ke moeti, ke Morena,
#
# Ya etetseng ho wena.
#
# Jo, mohlolo wa lerato!
#
# Tsoha, bula monyako!
#
# 2 Utlwa, utlwa, ke eena
#
# Ya kokotang ka matla:
#
# Leha monyako o hana,
#
# O nts'a leka ho kena;
#
# O sa eme, ke mohlolo.
#
# Oho, bula monyako!
#
# 3 Leha o diehile,
#
# O sa le teng le jwale,
#
# Bona madi le maqebq,
#
# O balaetswe wena.
#
# Ke Jesu, Mor'a Modimo;
#
# Mo bulele monyako!
#
# ----------------------------------------
#
# Lyrics for Ke moeti, ke le tseleng:
# 1. Ke moeti, ke le tseleng,
#
# Ke feta ke tsamaya,
#
# Leha tsela e le bothateng,
#
# Ke labile hae.
#
# Fifi lona le k aba teng,
#
# Nka 'na ka tsieleha;
#
# Ana nka belaela ke'ng?
#
# Ke labile hae.
#
# 2. Mona ke 'musong wa dira,
#
# Makhotla a ntikile,
#
# A rwar; ke tswela pele,
#
# Ke labile hae.
#
# Mohlomong ke fela pelo,
#
# ke ya imelwa, ke ya lela;
#
# Leha ho le hotshot-hotsho,
#
# Ke labile hae.
#
# 3. Ke melekong ka matsatsi,
#
# Ke hlora, ke teneha,
#
# Ke mpa ke sa qopheletse,
#
# Ke labile hae.
#
# Leha tlala e mpolaya,
#
# Ke tsoile ditlhabela,
#
# Ke khathala, ke nyediswa,
#
# Ke labile hae.
#
# 4. O teng ya ntlosang bodutu,
#
# Ya ntjarelang bothata;
#
# Ha ke mong, ken a le Jesu,
#
# Ke labile hae.
#
# Wa mpoloka, wa nqobela,
#
# O mphemisa maraba;
#
# Ka khotso ke ntse ke fenya,
#
# Ke labile hae.
#
# 5. di se di tla ba morao
#
# Tsa tsela, tsa kajeno,
#
# Mahloko le matshoenyeho,
#
# Ke ya fihla hae.
#
# Jo, thabo e tla ba kaakang,
#
# Ha ke bona Morena,
#
# E le eena ya ntlhapisang,
#
# Ke fihlile hae.
#
# ----------------------------------------
#
# Lyrics for Ke mofere, ke bofifi fela:
# 1. Ke mofero, ke bofi fela
#
# Tseleng tsa Jerusalema;
#
# Ke dithako, ke lepala-pala,
#
# Ke motes wa Morena.
#
# Bakhethwa, rapellang Jerusalema,
#
# Mo rapelleng le hlomohile pelo;
#
# Mo lleleng ka meokho, ke khutsana,
#
# Mots'o motle wa heso.
#
# 2. Pina tsa mekete di fedile
#
# Motseng wa Jerusalema.
#
# Jo, maswabi a khwahetse bohle,
#
# Baholo le ka bana.
#
# Bakhethwa, rapellang …
#
# 3. Jo, motse o motle, o ratehang,
#
# ...
#
# Le tlile dijong tsa lona;
#
# Fu la hae ho le hopola
#
# A be a tle. (bis)
#
# 2. 'Mele wa hae le o ngwathe,
#
# Motho e mocha a fepjwe,
#
# Mofokolo e tl'e fele,
#
# A be a tle. (bis)
#
# 3. Madi a hae le inwelle
#
# A hlakolang dibe tsohle,
#
# Efela le pholohile,
#
# A be a tle. (bis)
#
# 4. Le etseng 'mele o le mong,
#
# Ho rataneng le ho hlwekeng,
#
# Le lelalle lehodimong,
#
# A be a tle. (bis)
#
# 5. tshepo ya khanya e tshwareng,
#
# Le se le tla 'mona khanyeng;
#
# Mo lebelleng, mo lakatseng,
#
# A be a tle. (bis)
#
# ----------------------------------------
#
# Lyrics for Ho wena re tlisa dillo:
# 11.10.11.10.
#
# 1. Ho wena re tlisa dillo tsa rona,
#
# Modisa e Moholo wa dinku;
#
# Oho, sheba ka mosa mohlatswana
#
# Oo o ikhethetseng oona, Jesu!
#
# 2. U ka bona, khale re senyehile,
#
# Re tletse bobe bo sa phekoloeng;
#
# Se re lahle, Morena, tlo kapele,
#
# Wena, tshabelo sa ba thethetsweng!
#
# 3. Ha esale re itlotsa ho wena,
#
# Sefate sa 'nete sa bophelo,
#
# Thabo e fedile pelong tsa rona,
#
# Ho fedile le eona tebello.
#
# 4. Ha re san a matla a ho khumama,
#
# Re tennoe le ke tsa evangedi;
#
# Le dilampi tsa rona dia tima,
#
# Hobane disa tsheloe odi.
#
# 5. diphuthehong ha ho sa utlwahala
#
# Dillo tsa ba pelo tse hlabiloeng;
#
# Thoko tsa hao ha di sa re hlomola,
#
# Le jalo tse ntle di wela tseleng.
#
# 6. di kae tshiu tsa lerato la pele,
#
# Ha re ne re sa o chasehela?
#
# Rato leo, jo, le se le fetile,
#
# Ho setseng ke ho teneha fela.
#
# 7. Tlo, Mong'a Kereke, etsa ka matla,
#
# Tsosa banaba hao ba robetseng;
#
# Ratong la hao, leha o ka re otla,
#
# Re re: Ahe, fela re ntshe bobeng!
#
# ----------------------------------------
#
# Lyrics for Ho eena ya ka re sitsang:
# Ho eena ya ka re sitsang
#
# Ho fetisa ho kopa
#
# Le ho hopola ha rona, (bis)
#
# Ho iswe khanya phuthehong
#
# Ka mehla le mehla!
#
# ----------------------------------------
#
# Lyrics for Itlakoleng lillo:
# 13.12.13.12.13.12.
#
# 1 Itlhakoleng lillo, ha ba shoa, ba faletse
#
# Baa le ba ratileng e n'e le basele
#
# Le baeti mona, moo ba neng ba sepetse;
#
# Ba batla Molimo, 'me o ba latile;
#
# Ba kene ba timetse;  che ba re rakile. Bis
#
# 2 Ba ne ba imeloa hakaakang fatšeng lena
#
# Ke libe tsa bona tse neng li atile.
#
# Ba batla phomolo, joale ba e bone.
#
# Mabitleng a bona ba tšohela Morena.
#
# Se reng ba timetse; che, ba re rakile. Bis
#
# 3 Ho hotle ho bafu ba fumaneng bophelo;
#
# Ba bona Molimo, bohle bathabile;
#
# Ba ntse ba tlatsana lifelong tsa lerato,
#
# Etsoe tlase ba ne ba se ba qalile.
#
# Re bineng le bona ho leboha Molimo!
#
# Se reng ba timetse; che, ba re rakile. Bis
#
# ----------------------------------------
#
# Lyrics for Itleleng pel'a Morena:
# 1 Itleleng pel'a Morena
#
# Re itlhahise ho eena;
#
# Tlong, re roriseng molemo
#
# Le lerato la Molimo.
#
# 2 Jesu, 'Moloki o batla
#
# Baetsalibe kaofela;
#
# O ba ratile haholo
#
# O ba utloetse bohloko.
#
# 3 Ha re rapela Jehova,
#
# Ha re mo rata ka mehla
#
# Re tla fumana molemo,
#
# Re tla bona leholimo.
#
# ----------------------------------------
#
# Lyrics for Jehova Modimo, ke ngosa khauhelo:
# 13.12.13.12.
#
# 1 Jehova, Modimo, ke ngosa khauhelo,
#
# Ke se na tokelo khalalelong ya hao;
#
# Se ntoketseng fela ke lefu le ho tsuwa,
#
# Mahlong a hlwekileng a mponang ditshila.
#
# 2 Thapelo o tlwa ya motho ya lokileng;
#
# Anthe ya lokileng ke wena o 'notshi,
#
# Wena eo Mor'a hao a jereng sebe sa ka.
#
# 'Me kajeno a emetseng ho nthapella.
#
# 3 Ke 'na ya molato, o shwele bakeng sa ka,
#
# A shwa a ntopolla lefung le sa feleng,
#
# Ke re, ke hlatsuoe mading a sefapano,
#
# Ke iswe ke Moya tseleng tseleng ya poloko.
#
# 4 Ke re, ke chabeloe ke tsatsi la ho loka.
#
# Ho ele, ho hloeke, pelong ena ya ka;
#
# Tsohle tse ka ho 'na di tlotlishe Morena,
#
# Ke fumane khotso, tholo, le phomolo.
#
# ----------------------------------------
#
# Lyrics for Jehova Molimo, ke ngosa khauhelo:
# 13.12.13.12.
#
# 1 Jehova, Molimo, ke ngosa khauhelo,
#
# Ke se na tokelo khalalelong ea hao;
#
# Se ntoketseng fela ke lefu le ho tsuoa,
#
# Mahlong a hloekileng a mponang litšila.
#
# 2 Thapelo u tloa ea motho ea lokileng;
#
# Anthe ea lokileng ke uena u 'notši,
#
# Uena eo Mor'a hao a jereng sebe sa ka.
#
# 'Me kajeno a emetseng ho nthapella.
#
# 3 Ke 'na ea molato, o shoele bakeng sa ka,
#
# A shoa  a ntopolla lefung le sa feleng,
#
# Ke re, ke hlatsuoe maling a sefapano,
#
# Ke isoe ke Moea tseleng tseleng ea poloko.
#
# 4 Ke re, ke chabeloe ke tsatsi la ho loka.
#
# Ho ele, ho hloeke, pelong ena ea ka;
#
# Tsohle tse ka ho 'na li tlotlishe Morena,
#
# Ke fumane khotso, tholo, le phomolo.
#
# ----------------------------------------
#
# Lyrics for Jehova, Moren'a topollo:
# 1. Jehova, Moren'a topolla ya ka,
#
# Ho wena ke beile tshepo eohle.
#
# Matla a mahlomola a nkopa,
#
# A mphahamela; hlo o mpholose!
#
# 2. Ruri ha ho moemedi difatsheng
#
# Ho ntshedisa dillong le ditsietsing.
#
# Nka leba kae, ha e se ho wena?
#
# Rato la hao ke tshabelo sa ka.
#
# 3. Motho ya soto ya bitsang ho wena,
#
# Pelo ya hao e tla mo sekamela.
#
# Lona b akhathetseng, tlong ho eena,
#
# O tla khatholla pelo tsa lona.
#
# 4. Holane ke se na tumelo ena,
#
# Nka be ke hlolwa ke meleko ya ka.
#
# Empa Modimo ke ya nkemelang;
#
# Ha ho phahlo tse ka ntshithabetsang.
#
# 5. Ha ke le bohloko, le madimabe,
#
# Ke ntse ke thabela khotso ya 'nete.
#
# Ha ke tshohe letho; nka tshaba eng?
#
# Ke na le Modimo o sa sitoeng.
#
# ----------------------------------------
#
# Lyrics for Jehova, moren'a rona:
# 1 Jehova, Moren'a rona,
#
# Re ntse re phela ka uena;
#
# Ka mengoaha le mengoahla,
#
# U setšabelo sa rona.
#
# 2 Lithaba li e-s'o tsoaloe,
#
# Lefatše le e-s'o bopjoe,
#
# Esale u le Molimo,
#
# U sab aloe le lilemo.
#
# 3 Batho bohle ke lerole,
#
# Ho uena e ka lithole,
#
# Ha u re ho bona: khutlang!
#
# Eba batho ba fela hang,
#
# 4 Ba joale ka matlakala
#
# A kukoang ke likhohola;
#
# Ba feta joale ka toro
#
# E ikelang le bosiu.
#
# 5 Ba tšoana le joang hosasa,
#
# Bo phakisang ho palesa;
#
# Mantsiboea ha bo heloa
#
# Bo phakise ho omella.
#
# 6 Bohale ba ha obo tukang
#
# Ke bona bo rona,Morena,
#
# Libe tsa rona, Morena,
#
# Li bitsa kotlo ea rona
#
# 7 U li bea pepeneneng,
#
# U li hlahisa leseling,
#
# Li bonoe tsohle ke uena.
#
# Le tse patiloeng ke rona.
#
# 8 tšiu tsa rona li ile,
#
# Le lilemo li felile;
#
# Lemo tsee re li baletsoeng
#
# Li mashome a supileng.
#
# 9 Oho! Re rute Morena,
#
# Ho bala tšiu tsa rona
#
# Tse khutšoanyane, tse felang
#
# Ebe moo re hlalefisoang,
#
# ----------------------------------------
#
# Lyrics for Jehova, mo tsamaise:
# 1 . Jehova, mo tsamaise
#
# (Please Lead him God)
#
# Ngwan’a hao ya sepelang
#
# (Your child going astray)
#
# Ke phaila ke tsietswe
#
# Tseleng moo ke hlahlathang.
#
# (I’m just wondering not knowing where to go.)
#
# Jehova, (bis)
#
# (O God!)
#
# Ntate, ke o tshepile.
#
# (bis)
#
# (I trust in You.)
#
# Ntate, o se fele pelo
#
# (My Father don’t give up on me)
#
# Ha ke ntse ke kheloha;
#
# (Even though I keep going astray)
#
# Ho lefifi, ha se booma,
#
# (It’s so dark out here,)
#
# Ke timellwa ke tsela.
#
# (I dont know where to go.)
#
# Jehova, (bis)
#
# (O God!)
#
# Se lese ho ntsamaisa! (bis)
#
# (Please don’t stop leading me.)
#
# Leha ke khoehla mangole,
#
# (Though my knees are weak,)
#
# Ke pheela, ke khasa;
#
# (I Keep striving;)
#
# Ba heso, ba ntshiile bohle,
#
# (All my family have left me alone,)
#
# Na nka lahlwa ke wena?
#
# (Will You forsake me too?)
#
# Jehova, (bis)
#
# (O God!)
#
# U ntlheke o ntse o mpepa. (bis)
#
# (Take hold of me.)
#
# dira ke di sheba mahlong,
#
# (My enemies are before me,)
#
# Ke tsheha ditsietsi;
#
# (I laugh at my misery;)
#
# Ha ho tshabo, ha ho dihlong,
#
# (I have no fear nor shame,)
#
# U ho ‘na, ha ke ‘notshi;
#
# (I am not alone;)
#
# Jehova, (bis)
#
# (O God!)
#
# U se khaohane le ‘na. (bis)
#
# (Don’t forsake me.)
#
# Ha ke tshela noka e ntsho,
#
# (When i go though the valley of the shadow of death,)
#
# Ke nyahama, ke teba,
#
# (I have no fear,)
#
# U mpalamise maqhubu,
#
# (Lead me through it all,)
#
# U ntshike ka diatla;
#
# (Hold me with your Holy hands)
#
# Jehova, (bis)
#
# (O God!)
#
# U mphihlise ha hao le ‘na. (bis)
#
# (And lead me to life everlasting.)
#
# ----------------------------------------
#
# Lyrics for Jerusalema e mocha:
# 1. Jerusalema e mocha,
#
# Motse o moholo
#
# O theohang ho Modimo,
#
# O motle, wa khanya.
#
# Sedi la hao ke le fahlang
#
# Jwale ka lehakoe,
#
# Lehakoe le bonaletsang
#
# Ho feta daemane.
#
# 2. Motse ona ha o batle
#
# Hore o boneswe;
#
# O boneswa ke Modimo
#
# Ka khanya ya Jesu.
#
# Letsatsi ha le sa chaba,
#
# E fetile khoedi;
#
# Molala le dinaledi
#
# Ha di sa phatsima.
#
# 3. Chaba tsohle tsa lefifi
#
# Di tla tla kaofela,
#
# Di tla phallela lesedi,
#
# Le 'ona marena.
#
# Motse, nyene, le bosiu,
#
# O nts'o bulehile;
#
# Ha ho sa le motsheare,
#
# Bosiu ha bo eo.
#
# 4. Teng ho tla tliswa hlonepho,
#
# Khanya ya dichaba;
#
# Tshila di ke ke tsa kena,
#
# Le bona bokhopo.
#
# Ka teng ho tla kena fela
#
# Ba ngodiloeng bukeng;
#
# Buka eo ke ya Konyana,
#
# Konyana e hlotseng.
#
# ----------------------------------------
#
# Lyrics for Ba bitseng le ba qophelle:
# 1 Ba bitseng, le ba qophelle,
#
# Bahlomphehi le marena;
#
# Se feteng hlotsa, sehole,
#
# Le sona sekhwahlapa!
#
# Ba bitseng, le ba qophelle
#
# Har'a metse le naheng!
#
# Pheellang, ha batleng hohle,
#
# Ba tle bohle moketeng!
#
# 2 Ba bitseng, le ba qophelle,
#
# Baholo le maqhekwana,
#
# Ba bacha le ba bohlale,
#
# Ba dithoto le bana!
#
# Ba bitseng, le ba qophelle.
#
# Tsamayang, se ba kheseng!
#
# Pheellang, ba batleng hohle,
#
# Ba tle bohle moketeng!
#
# 3 Ba bitseng, Ie ba qophelle,
#
# Ba madimabe, ba hlorang;
#
# Ba lefifing, ba lahlehang,
#
# Hleka ba ka phela jwang?
#
# Ba bitseng, le ba qophelle,
#
# Tsamayang, le ba lateng;
#
# Tlerolang, ho dumaele,
#
# Ba tle bohle moketeng!
#
# 4 Ba bitseng, le ba qophelle
#
# Bahedene ba dichabeng;
#
# Le hleng le ba hauhele,
#
# Ba timella lefifing!
#
# Le diehetse'ng hakale,
#
# Pelo di fodile ke'ng?
#
# Tswang mahae, le ba phallele,
#
# Ba tle bohle moketeng!
#
# 5 Ba bitseng, le ba qophelle,
#
# Phakisang, ho feta nako,
#
# Phallang, tumisang kahohle
#
# Ditaba tsa topollo!
#
# Tsohle di se di lokile,
#
# Ba biletswa Moreneng.
#
# Ba lateng, le ba qophelle,
#
# Ba tle bohle moketeng!
#
# ----------------------------------------
#
# Lyrics for Jerusalema e mocha:
# 1. Jerusalema e mocha,
#
# Motse o moholo
#
# O theohang ho Molimo,
#
# O motle, oa khanya.
#
# Seli la hao ke le fahlang
#
# Joale ka lehakoe,
#
# Lehakoe le bonaletsang
#
# Ho feta daemane.
#
# 2. Motse ona ha o batle
#
# Hore o bonesoe;
#
# O bonesoa ke Molimo
#
# Ka khanya ea Jesu.
#
# Letsatsi ha le sa chaba,
#
# E fetile khoeli;
#
# Molala le linaleli
#
# Ha li sa phatsima.
#
# 3. Chaba tsohle tsa lefifi
#
# Li tla tla kaofela,
#
# Li tla phallela leseli,
#
# Le 'ona marena.
#
# Motse, nyene, le bosiu,
#
# O nts'o bulehile;
#
# Ha ho sa le motšeare,
#
# Bosiu ha bo eo.
#
# 4. Teng ho tla tlisoa hlonepho,
#
# Khanya ea lichaba;
#
# Tšila li ke ke tsa kena,
#
# Le bona bokhopo.
#
# Ka teng ho tla kena fela
#
# Ba ngoliloeng bukeng;
#
# Buka eo ke ea Konyana,
#
# Konyana e hlotseng.
#
# ----------------------------------------
#
# Lyrics for Jerusalema, ua benya:
# 1 Jerusalema, ua benya,
#
# Kaho e tsoang limonite;
#
# U khabisitsoe ka khanya,
#
# Motse o busoang ke Ntate.
#
# 2 Ke tla  aha ho uena neng,
#
# Mohlophehi oa Molimo,
#
# Ka sabatha e sa feleng,
#
# Phuthehong ea leholimo? (bis)
#
# 3 Lefu ke sa le tšoha joang,
#
# Le lififi la lebitla?
#
# Ke na le motse o khanyang,
#
# Le leseli la ka mehla .
#
# 4 Jerusalema e mocha,
#
# Fatše la ka la phomolo,
#
# Ke hlolohetsoe ho kena
#
# Ha hao, ke neoe bophelo.(bis
#
# ----------------------------------------
#
# Lyrics for Jerusalema ya phatsimang:
# 1 Jerusalema ya phatsimang,
#
# Lefatshe la pallo,
#
# U motle-motle hakaakang,
#
# Motes wa phomolo!
#
# Maru, dirame, difefo,
#
# Ho wena ke tse leng sieo;
#
# Se teng ke thabo, ke khotso,
#
# Motse wa phomolo.
#
# Jerusalema, Jerusalema,
#
# Motse wa phomolo!,
#
# 2 Jerusalema ya ratehang,
#
# Motse wa topollo;
#
# Hae la ntate le khahlehang,
#
# Motse wa phomolo!
#
# Tlamo tse thata tsa sebe,
#
# Ho wena ha ba di tsebe;
#
# Ke tokollo, ke poloko
#
# Motseng wa phomolo.
#
# Jerusalema, Jerusalema,
#
# Motse wa phomolo!
#
# 3 Jerusalema, ya khabane
#
# Motse wa lerato;
#
# U motle, o hlophehile,
#
# Motse, wa phomolo!
#
# Ha ke fihla, ho tla ba jwang,
#
# Nyakallo e tla ba kakaang
#
# ke o boha ka mahlo,
#
# Motse wa phomolo.
#
# Jerusalema, Jerusalema,
#
# Motse wa phomolo!
#
# ----------------------------------------
#
# Lyrics for Jesu a shwa 'me a tsoha bafung:
# 1. Jesu a shwa, 'me a tsoha bafung,
#
# Topollo e phethiloe.
#
# Jwale, ken a le khotso ka pelong,
#
# Ke bolokehile.
#
# Esita le 'na,
#
# Moetsadibe,
#
# Jesu ke 'Moloki wa ka,
#
# Ke bolokehile.
#
# 2. tshila, melato ya dibe tsa ka,
#
# Jesu o di khofile;
#
# Ke tswaretswe, ke bone ho phela,
#
# Ke bolokehile.
#
# Esita le 'na, …
#
# 3. Leha lefatshe le ka nthuntshetsa,
#
# Ke sa ntse ke tshepile,
#
# Jesu o sa nkapesa ho loka;
#
# Ke bolokehile.
#
# Esita le 'na, …
#
# 4. Satane a ka ntshoenya, a nteka,
#
# A rora ka bohale,
#
# Jesu o teng, ke sefela saka,
#
# Ke bolokehile.
#
# Esita le 'na, …
#
# 5. Ke dutse ho Jesu, ke phomola
#
# Monateng, ho edile;
#
# Fifi ha le san a ho nkwahela,
#
# Ke bolokehile.
#
# Esita le 'na, …
#
# 6. Lefu, Morena wa matshabeho,
#
# Ha ke le thothomelle; …
#
# Jesu o ntshikile ka matsoho,
#
# Ke bolokehile.
#
# Esita le 'na, …
#
# ----------------------------------------
#
# Lyrics for Jesu, bohobe ba bophelo:
# 9.8.9.8.D.
#
# Jesu, bohobe ba bophelo,
#
# Veine e kholisang moea,
#
# Mong'a litaba tsa tšoarelo,
#
# Ea tlosang libe tsa rona.
#
# Pelo ea ka e hlomohile,
#
# Ha ke  boha lefu la hao;
#
# Ak'u ntšepise ka sebele,
#
# Ke tle ke khore mohau.
#
# ----------------------------------------
#
# Lyrics for Jesu, bohobe ba bophelo:
# 9.8.9.8.D.
#
# Jesu, bohobe ba bophelo,
#
# Veine e khodisang moya,
#
# Mong'a ditaba tsa tshwarelo,
#
# Ya tlosang dibe tsa rona.
#
# Pelo ya ka e hlomohile,
#
# Ha ke boha lefu la hao;
#
# Ak'u ntshepise ka sebele,
#
# Ke tle ke khore mohau.
#
# ----------------------------------------
#
# Lyrics for Jesu, ha ke batle thuso:
# 1 Jesu, ha ke batle thuso
#
# Tse ngata, tse fetang,
#
# Ha e se tse ka ntekanang
#
# La kajeno fela.
#
# U hana dipelaelo,
#
# U ntse o laela tshepo.
#
# Ke tla 'ne ke o tshepe,
#
# Ke o khomarele,
#
# Ke dule maotong a hao,
#
# Ke ntse ke lebeletse
#
# Ketso tsa thato ya hao.
#
# 2 Jesu, ke batla ho le hong:
#
# Ke ho o khahlisa
#
# Diketsong le mehopolong,
#
# Bothong bohle ba ka.
#
# Ke be ngwan'a hlokolotsi,
#
# Ya sa tl'o tshoha lesitsi.
#
# Ke tla 'ne ke o tshepe, …
#
# 3 Jesu, mpontshe sefapano
#
# See o ka se bonang,
#
# E seng sa boikhethelo,
#
# E le se ntekanang,
#
# Sa boitelo bo tletseng,
#
# Mamello e sa khathaleng.
#
# Ke tla 'ne ke o tshepe,
#
# 4 Jesu, ha ke tla tsamaya,
#
# Mose ke tshelela,
#
# E be hle ho ya ho wena,
#
# Wena, Moratuwa.
#
# E be ke moo ke tla hlola
#
# Ka ho sa eeng kae, ka mehla.
#
# Ke tla 'ne ke o tshepe,
#
# ----------------------------------------
#
# Lyrics for Jesu, ha o ile:
# 1. Jesu, ha o ile
#
# Wa siea taelo,
#
# U itse, re o hopole,
#
# Ha re ja selallo
#
# 2. Re ka lebala jwang
#
# Rato le leholo,
#
# Le tsotisang, le makatsang
#
# La Morena Jesu?
#
# 3. Re ka lebala jwang
#
# Bitso le monati
#
# La 'Moloki ya ratehang,
#
# Ya hlotseng Satane?
#
# 4. Re ka lebala jwang
#
# Madi a Konyana,
#
# A tsholotsweng sefapanong;
#
# A tsolletsweng rona?
#
# 5. re ya o Hopola
#
# re ya o lakatsa,
#
# Mohauhedi wa rona,
#
# re ya o lebella.
#
# ----------------------------------------
#
# Lyrics for Jesu, ha u ile:
# 1.	Jesu, ha u ile
#
# Ua siea taelo,
#
# U itse, re u hopole,
#
# Ha re ja selallo
#
# 2.	Re ka lebala joang
#
# Rato le leholo,
#
# Le tsotisang, le makatsang
#
# La Morena Jesu?
#
# 3.	Re ka lebala joang
#
# Bitso le monate
#
# La 'Moloki ea ratehang,
#
# Ea hlotseng Satane?
#
# 4.	Re ka lebala joang
#
# Mali a Konyana,
#
# A tšolotsoeng sefapanong;
#
# A tsolletsoeng rona?
#
# 5.	Rea u Hopola
#
# Rea u lakatsa,
#
# Mohauheli oa rona,
#
# Rea u lebella.
#
# ----------------------------------------
#
# Lyrics for Jesu, ke ya baba:
# 1 Jesu, ke ya baba, ke ya o llela;
#
# Hoja o ka dula ho 'na ka mehla,
#
# ke ya hlora, Jesu, ke ya o bitsa,
#
# Ntlhatswe, ke be mosweo le ho lehlwa,
#
# Mosweo, e, ho feta lehlwa;
#
# Ntlhatswe, ke be mosweo le ho lehlwa,
#
# 2 Se qene pelo ya moetsadibe,
#
# Leha e le ditshila le manyala,
#
# Oho kena, fedisisa bobe!
#
# Ntlhatswe, ke be mosweo le ho lehlwa
#
# Mosweo, e, ho feta lehlwa…
#
# 3 Phuphuthela medimo ya mefuta,
#
# Le dira tse ntwantshang tse hare ho 'na.
#
# Ke khathetse; ke ya shwa ha o ntahla!
#
# Ntlhatswe, ke be mosweo le ho lehlwa.
#
# Mosweo, e, ho feta lehlwa…
#
# 4 Thole tsa mehopolo e khesehang,
#
# Tsohle tse ntshitang le ho di bolela,
#
# U di ntshe, wena ya ntsokodisisang.
#
# Ntlhatswe, ke be mosweo le ho lehlwa
#
# Mosweo, e, ho feta lehlwa…
#
# 5 dikhapha tsa ka ha di na le thuso,
#
# Sebe se ntse se rusetsa ka matla.
#
# ke ya baba, mong'a ka ya lerato,
#
# Ntlhatswe, ke be mosweo le ho lehlwa
#
# Mosweo, e, ho feta lehlwa…
#
# 6 Kena ka borena ka pelong ya ka,
#
# Busa hona teng, e ruuoe ke wena.
#
# U ntlhoekise, Jesu se nkhane le 'na.
#
# Ntlhatswe, ke be mosweo le ho lehlwa.
#
# Mosweo, e, ho feta lehlwa…
#
# ----------------------------------------
#
# New hymns data with lyrics has been saved to hymns_sione.json.
